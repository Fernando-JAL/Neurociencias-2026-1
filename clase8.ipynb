# %%
import numpy as np

# %%
np.random.rand()
# Out:
# 0.6577085993744906

# %%
a,b=10,15
np.random.uniform(a,b,size=[3,4]) #uniform es cuando la prob de obtener un num entre a y b es la misma
# Out:
# array([[11.70847442, 14.81139624, 12.8949909 , 12.53357301],
#        [10.25529151, 14.04297768, 12.29015317, 12.40100753],
#        [11.32121826, 10.15698868, 10.89185674, 14.96613681]])

# %%
np.random.randint(10, size=[8]) #num enteros del 0 al 10
# Out:
# array([0, 7, 6, 2, 3, 3, 7, 0], dtype=int32)

# %%
valores=np.random.normal(0,1,size=10000)
np.mean(valores), np.std(valores)
# Out:
# (np.float64(0.00453731998917025), np.float64(0.9829656958858584))

# %%
vec1,vec2= np.array([2,3,4]),np.array([-1,-10,0])
np.vdot(vec1,vec2) #producto punto
# Out:
# np.int64(-32)

# %%
vec2.sort()
vec2[::-1]
# Out:
# array([  0,  -1, -10])

# %%
import pandas

# %%
import matplotlib.pyplot as plt #para graficar

# %%
valores= np.arange(20) #arange nos da un arreglo de num del 0-20
plt.plot(valores,marker="*")

# %%
valores= np.random.uniform(size=5)
plt.hist(valores)
# Out:
# (array([1., 0., 1., 0., 1., 0., 1., 0., 0., 1.]),
#  array([0.05246426, 0.12216919, 0.19187411, 0.26157904, 0.33128396,
#         0.40098889, 0.47069381, 0.54039874, 0.61010366, 0.67980859,
#         0.74951351]),
#  <BarContainer object of 10 artists>)

# %%
numeros= np.random.normal(0,1,size=100000)
np.mean(numeros),np.std(numeros)

plt.hist(numeros, bins=1000);

# %%
import pandas as pd

# %%
pd.Series([4,5,6,7,8,9,"cosa"])
# Out:
# 0       4
# 1       5
# 2       6
# 3       7
# 4       8
# 5       9
# 6    cosa
# dtype: object

# %%
pd.Series(["a","b"])
# Out:
# 0    a
# 1    b
# dtype: object

# %%
pd.Series(range(50,56), index=["a","b","c","d","e","f"])
# Out:
# a    50
# b    51
# c    52
# d    53
# e    54
# f    55
# dtype: int64
