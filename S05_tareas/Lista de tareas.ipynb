# %% [markdown]
# # Tareas
#
# - TAREA de calcular con loop y con recursividad dos funciones
# - Tarea de investigar los métodos con networkx para las métricas de grafos. Se uso para examen, tons ya cumplida
# - TAREA de investigar en qué casos se utilizaba cada método para generar la matriz de conectividad: correlación de Pearsion, coherencia espectral y PLV
# - Tarea de investigar diferencias entre Conectividad Estructural y Conectividad Funcional. Hubo discución
# - TAREA para derecho a examen
