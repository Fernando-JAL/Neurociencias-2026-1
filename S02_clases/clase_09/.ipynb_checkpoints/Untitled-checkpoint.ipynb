# %%
import numpy as np

# %%
np.random.rand(6,2)
# Out:
# array([[0.83486761, 0.25531968],
#        [0.38221372, 0.02522367],
#        [0.14619721, 0.88065565],
#        [0.77796568, 0.67684372],
#        [0.98656737, 0.69016345],
#        [0.79723318, 0.22220993]])

# %%
a,b= 10,15
np.random.uniform(a,b,size=[3,4])
# Out:
# array([[13.36628817, 11.1936642 , 10.0188684 , 13.21705224],
#        [10.00943765, 12.37129638, 12.01471266, 11.30873468],
#        [10.14664323, 12.24036905, 14.73546645, 13.00170835]])

# %%
np.random.randint(10,size=[8])
# Out:
# array([6, 8, 9, 6, 6, 1, 3, 9], dtype=int32)

# %%
np.random.normal()
# Out:
# 0.020242428442100748

# %%
mu, sigma = -8,4
np.random.normal(mu, sigma, size=[2,6])
# Out:
# array([[ -1.58188119,  -8.66363049,  -6.71715986,   1.47802876,
#          -2.74402176,  -6.55864203],
#        [ -2.83156121,  -6.85746082, -10.59039114, -10.94548768,
#          -3.28718045, -13.15654231]])

# %%
valores = np.random.normal(0,1, size=100000)
np.mean(valores), np.std(valores)
# Out:
# (np.float64(0.0017027808713603598), np.float64(1.0012332750128794))

# %%
vec1, vec2 = np.array([2,3,4]), np.array([-1,-10,0])
np.vdot(vec1, vec2)
# Out:
# np.int64(-32)

# %%
vec2.sort()
vec2[::-1]
# Out:
# array([  0,  -1, -10])

# %%
import matplotlib.pyplot as plt

# %%
valores = np.arange(20)
plt.plot(valores, '.')

# %%
valores = np.random.uniform(size=5)
plt.hist(valores)
# Out:
# (array([1., 1., 0., 0., 0., 1., 0., 0., 0., 2.]),
#  array([0.15357429, 0.23346364, 0.31335299, 0.39324234, 0.47313169,
#         0.55302104, 0.63291038, 0.71279973, 0.79268908, 0.87257843,
#         0.95246778]),
#  <BarContainer object of 10 artists>)

# %%
#Cree una arreglo d enumeros aleatorios con distribucion normal con media mu=0 y desviacion estandar =1 de tamaño 100, 000 y plotear su histograma

# %%
valores = np.random.normal(0,10, size=100000)
plt.hist(valores, bins=100);

# %%
import pandas
