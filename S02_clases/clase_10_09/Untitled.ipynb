# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx

# %%
file = r"C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S03_datasets\BCT\macaco_M132_F99_LH.csv"

# %%
df = pd.read_csv(file)

# %%
df
# Out:
#    region     x     y     z
# 0      V1 -13.2 -76.5   7.5
# 1      V2 -11.1 -70.4  10.2
# 2      V3  -9.3 -66.1  11.9
# 3     V3A -12.8 -61.9  13.9
# 4      V4  -7.8 -57.8  13.1
# 5     V4t  -9.6 -54.7  11.8
# 6      MT -22.4 -59.7   1.8
# 7    MSTd -21.6 -53.1  13.6
# 8    MSTl -20.9 -50.2  12.3
# 9     LIP -18.7 -41.9  25.4
# 10    VIP -22.1 -34.8  24.2
# 11    PIP -17.4 -35.8  15.4
# 12     PO -16.5 -32.2  19.8
# 13    FEF -10.4  15.1  27.4
# 14     46  -8.1  31.9  25.9
# 15     7a -17.2 -37.1  31.5
# 16     7b -18.9 -32.7  27.8
# 17    SMA  -4.2   6.5  32.2
# 18      6 -12.6 -10.7  31.9
# 19      4 -17.1 -21.5  28.1
# 20     3a -17.6 -31.5  24.8
# 21     3b -18.9 -33.1  23.6
# 22      1 -18.3 -27.9  24.1
# 23      2 -19.1 -29.7  22.9
# 24      5 -18.4 -23.8  25.6
# 25     DP -18.1 -48.5  17.3
# 26    MDP -15.8 -45.7  19.1
# 27    MIP -17.9 -39.1  21.2
# 28    FST -22.0 -55.2   3.9
# 29   AITd -18.4 -10.2 -14.5
# 30   AITv -19.0 -14.6 -17.2
# 31   PITd -20.5 -24.7  -9.8
# 32   PITv -21.1 -28.5 -11.3
# 33   CITd -17.4 -20.3  -7.1
# 34   CITv -18.1 -22.9  -8.6
# 35    VOT -19.7 -18.2 -12.4
# 36     TF -14.8  -9.2 -11.8
# 37     TH -13.1  -5.9  -9.6
# 38     35 -12.0  -3.4  -7.5
# 39     36 -11.5  -6.1  -8.2
# 40     Id -23.6 -16.3  12.5
# 41     VP -14.1 -64.8   6.7
# 42     Ig -20.1 -23.9  22.6
# 43   STPa -20.4 -13.6   3.4
# 44   STPp -22.2 -16.8   2.1
# 45     Ri -19.5 -18.7  14.3
# 46    SII -21.9 -26.3  18.9

# %%
# %matplotlib widget
plt.figure(figsize=(4, 4))
plt.scatter(df['x'], df['y'], df['z'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
