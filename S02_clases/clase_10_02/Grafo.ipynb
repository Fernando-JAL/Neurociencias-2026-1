# %%
import networkx as nx

# %%
G = nx.Graph()

# %%
G.nodes(), G.edges()
# Out:
# (NodeView(()), EdgeView([]))

# %%
G.add_nodes_from(['A', 'B', 'C', 'D', 'E', 'F', 'G'])

# %%
G.nodes(), G.edges() #Preguntar los nodos y aristas que hay
# Out:
# (NodeView(('A', 'B', 'C', 'D', 'E', 'F', 'G')), EdgeView([]))

# %%
G.add_edges_from([ ('B', 'C'), ('C','A'), ('D', 'E'), ('A', 'D'), ('C', 'F'), ('E', 'G'), ('A', 'G'), ('D', 'B'), ('A', 'F'), ('C', 'E')])

# %%
G.nodes(), G.edges() #Preguntar los nodos y aristas que hay
# Out:
# (NodeView(('A', 'B', 'C', 'D', 'E', 'F', 'G')),
#  EdgeView([('A', 'C'), ('A', 'D'), ('A', 'G'), ('A', 'F'), ('B', 'C'), ('B', 'D'), ('C', 'F'), ('C', 'E'), ('D', 'E'), ('E', 'G')]))

# %%
nx.draw_networkx(G)
