# %% [markdown]
# prueba base de datos

# %%
import mne

# ruta al archivo
fname = r"C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-01_task-rsvp_continuous.set"

# cargar los datos (MNE lo abre directamente)
raw = mne.io.read_raw_eeglab(fname, preload=True)

print(raw)
# Out:
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-01_task-rsvp_continuous.fdt
# Reading 0 ... 758934  =      0.000 ...  3035.736 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3171578420.py:7: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(fname, preload=True)
# <RawEEGLAB | sub-01_task-rsvp_continuous.fdt, 64 x 758935 (3035.7 s), ~370.6 MiB, data loaded>
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3171578420.py:7: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(fname, preload=True)

# %%
import pandas as pd

# Convertir los datos completos a DataFrame
df = raw.to_data_frame()

print(df)
# Out:
#             time         Fp1         Fz         F3         F7        FT9  \
# 0          0.000  -18.718849   3.114996   0.699508 -25.903978 -10.220798
# 1          0.004  -13.751985   7.934219   2.261670 -24.238207  -4.785899
# 2          0.008   -0.646213  12.757488   2.047870 -21.501438  -1.299244
# 3          0.012   -4.287172   9.130175   0.451229 -29.563072 -14.166145
# 4          0.016  -12.503530   5.229737  -2.318077 -28.414206 -15.907533
# ...          ...         ...        ...        ...        ...        ...
# 758930  3035.720  -87.285393   1.276156 -39.478657 -98.659195 -45.364594
# 758931  3035.724  -97.674225  -3.455768 -42.262478 -98.011940 -49.550583
# 758932  3035.728 -104.228767  -4.359319 -46.054260 -97.994553 -50.301624
# 758933  3035.732  -96.600113  -0.847905 -43.962696 -99.463104 -52.629890
# 758934  3035.736  -85.413612   3.622068 -39.910282 -96.450302 -55.190174
#
#               FC5       FC1         C3         T7  ...         C6         C2  \
# 0       -4.386106  9.194303   6.221677  -5.273910  ...   9.314235  -1.428208
# 1       -4.344290  9.442557  -2.200526 -12.109086  ...   8.167401  -0.255947
# 2       -1.522489  9.568386   0.249126   1.395538  ...   8.168926  -2.564536
# 3       -7.756516  7.219606   0.853010 -25.400393  ...   4.701989  -6.124348
# 4       -6.500531  7.203659  -5.337641 -55.632130  ...  -1.428544  -3.726030
# ...           ...       ...        ...        ...  ...        ...        ...
# 758930 -33.990025  4.633817  -6.372640 -46.559071  ...  20.891035   8.255315
# 758931 -34.868523  4.244261  -8.301973 -33.075993  ...  17.652472   8.669466
# 758932 -44.535553 -0.692877 -15.151399 -14.722863  ...  29.145012  13.248218
# 758933 -34.158768 -0.741723  -5.384854 -42.136024  ...  16.535744  12.514408
# 758934 -32.972435  2.664833  -5.987292 -35.257832  ...  17.797140   8.741218
#
#               FC4        FT8         F6        AF8        AF4         F2  \
# 0        9.578927  19.573862  15.016768   0.007434  -5.099166   2.251824
# 1        9.090252  11.584027  15.031819   2.102934  11.423728   6.331036
# 2        9.184335  13.363972  16.361179   6.683286  21.685717   7.680823
# 3        6.859305  14.832430  14.021835   5.968809  15.938169   4.484838
# 4        4.948614   9.325240  14.718820   1.333427  14.058165   2.591611
# ...           ...        ...        ...        ...        ...        ...
# 758930  22.579905  61.659462  50.986164  59.980595   8.644125   9.410406
# 758931  23.582981  66.843086  50.678967  56.052231   0.937437   6.865257
# 758932  27.515846  72.764572  55.150257  55.111053  -0.808756   9.811886
# 758933  23.805014  57.441044  48.088394  49.274876   1.357081  10.672110
# 758934  22.731327  55.328186  47.639347  56.356453  10.913973  12.718354
#
#              FCz        Cz
# 0       6.296582  3.729200
# 1       6.511239  4.068888
# 2       4.050063  2.271664
# 3       0.942950  0.285410
# 4       4.385415  1.913909
# ...          ...       ...
# 758930  3.157724  7.139411
# 758931  3.899073  7.369058
# 758932  4.493230  7.655472
# 758933  5.504866  8.338042
# 758934  5.610395  7.228868
#
# [758935 rows x 65 columns]

# %%
valores = [188.78, 1798.92, 2467.60, 2863.86]

fila = df[df["time"].isin(valores)]#.iloc[0]
print(fila)
# Out:
#            time         Fp1          Fz          F3          F7         FT9  \
# 47195    188.78 -202.609177  -30.858923  -41.296055  -44.757885   38.856422
# 449730  1798.92  804.113037  105.598686  183.139313  194.965103 -142.825317
# 616900  2467.60  -81.640121  -11.579931  -17.993305  -18.112175   12.736830
# 715965  2863.86 -108.926201    8.000601  -10.372354  -21.145264   13.745917
#
#               FC5        FC1         C3          T7  ...          C6  \
# 47195    5.376462  -4.931069  12.846797   36.173038  ...   24.840717
# 449730  38.955025  16.940264 -23.311062 -113.522118  ... -101.903168
# 616900   0.868792  10.345144  12.457737    4.718727  ...   -4.943908
# 715965 -29.083298  -1.357717  -5.724850   16.476194  ...   13.165453
#
#                C2        FC4         FT8         F6         AF8         AF4  \
# 47195   12.103859   3.977032   26.804296  -9.558162 -110.671005  -74.240631
# 449730 -53.123833 -19.890545 -118.534836  53.401642  421.561920  232.104614
# 616900  15.833524   8.386654    8.413367  -2.334854  -48.906601  -22.034935
# 715965  18.257139  10.274996   22.534496   8.745576  -53.287231  -28.795576
#
#                F2        FCz         Cz
# 47195  -22.682159  -3.990096  15.399276
# 449730  85.736595   0.980248 -48.703014
# 616900  -7.151020   9.162766  20.274822
# 715965   5.039141  13.579064  18.728127
#
# [4 rows x 65 columns]

# %%
# ANIMALES

import pandas as pd
import glob

# Diccionario con el tiempo específico de cada sujeto
tiempos_por_sujeto = {
    "subj01": [188.78, 1798.92, 2467.60, 2863.86, 142.30, 988.93, 2090.69, 2677.90]
    "subj02": 3.1,
    # ...
}

for file in glob.glob("C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\*.set"):
    subj = file.replace(".set", "")

    raw = mne.io.read_raw_eeglab(file, preload=True)

    t = tiempos_por_sujeto[subj]

    # Encontrar índice del tiempo solicitado
    idx = raw.time_as_index(t)

    # Extraer la fila completa de canales en ese tiempo
    data, times = raw[:, idx]

    # Convertir a DataFrame
    df = pd.DataFrame(data.T, columns=raw.ch_names)

    df_animales.to_csv(f"{subj}_t{t}.csv", index=False)

    print(df_animales)
# Out:
#   Cell In[2], line 8
#     "subj01": [188.78, 1798.92, 2467.60, 2863.86, 142.30, 988.93, 2090.69, 2677.90]
#               ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# # Datos alimentos

# %%
# Filtrado de archivos .csv para obtener time_stimon de cada estímulo por sujeto

import pandas as pd
import glob
import os
import re

stimname_variables = ["apple_01b.jpg", "apple_02s.jpg", "apple_03s.jpg", "apple_04s.jpg", 
                      "avocado_01b.jpg", "avocado_02s.jpg", "avocado_03s.jpg", "avocado_04s.jpg", 
                      "banana_01b.jpg", "banana_02s.jpg", "banana_03s.jpg", "banana_04s.jpg", 
                      "beet_01b.jpg", "beet_02s.jpg", "beet_03s.jpg", "beet_04s.jpg",
                      "cheesecake_01s.jpg", "cheesecake_02s.jpg", "cheesecake_03s.jpg", "cheesecake_04s.jpg", 
                      "cherry_01b.jpg", "cherry_02s.jpg", "cherry_03s.jpg", "cherry_04n.jpg",
                      "hamburger_01s.jpg", "hamburger_02s.jpg", "hamburger_03s.jpg", "hamburger_04s.jpg",
                      "hotdog_01b.jpg", "hotdog_02s.jpg", "hotdog_03s.jpg", "hotdog_04s.jpg",
                      "lasagna_01b.jpg", "lasagna_02s.jpg", "lasagna_03s.jpg", "lasagna_04s.jpg",
                      "mango_01b.jpg", "mango_02s.jpg", "mango_03s.jpg", "mango_04s.jpg"

]

csv_files = glob.glob(r"C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-*_task-rsvp_events.csv")

resultados = []

for file_path in csv_files:
    try:
        df = pd.read_csv(file_path)

        # Extraer el nombre del archivo (ej: "sub-01_task-rsvp_events.csv")
        filename = os.path.basename(file_path)

        # Usar regex para sacar "sub-XX"
        match = re.search(r"(sub-\d+)", filename)
        subject_id = match.group(1) if match else "unknown"

        # Filtrar alimentos
        alimentos_df = df[df['stimname'].isin(stimname_variables)]

        # Seleccionar columnas
        selected = alimentos_df[['stimname', 'time_stimon']].copy()

        # Redondear
        selected['time_stimon'] = selected['time_stimon'].round(2)

        # Añadir columna del sujeto
        selected['subject'] = subject_id

        # Guardar
        resultados.append(selected)

        print(f"Processed {file_path}: Found {len(selected)} entries for {subject_id}.")

    except Exception as e:
        print(f"Error processing {file_path}: {e}")

# Concatenar
alimentos_df = pd.concat(resultados, ignore_index=True)

print("\nTotal rows collected:", len(alimentos_df))
print(alimentos_df.head())

# Crear columna numérica del sujeto
alimentos_df['subject_num'] = alimentos_df['subject'].str.extract(r'(\d+)').astype(int)

# Ordenar stimname según tu lista original
alimentos_df['stimname'] = pd.Categorical(
    alimentos_df['stimname'],
    categories=stimname_variables,
    ordered=True
)

# Orden final
alimentos_df = alimentos_df.sort_values(by=['subject_num', 'stimname']).reset_index(drop=True)

print(alimentos_df.head(20))
# Out:
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-01_task-rsvp_events.csv: Found 40 entries for sub-01.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-02_task-rsvp_events.csv: Found 40 entries for sub-02.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-03_task-rsvp_events.csv: Found 40 entries for sub-03.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-04_task-rsvp_events.csv: Found 40 entries for sub-04.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-05_task-rsvp_events.csv: Found 40 entries for sub-05.
# Error processing C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-06_task-rsvp_events.csv: 'stimname'
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-07_task-rsvp_events.csv: Found 40 entries for sub-07.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-08_task-rsvp_events.csv: Found 40 entries for sub-08.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-09_task-rsvp_events.csv: Found 40 entries for sub-09.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-10_task-rsvp_events.csv: Found 40 entries for sub-10.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-11_task-rsvp_events.csv: Found 40 entries for sub-11.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-12_task-rsvp_events.csv: Found 40 entries for sub-12.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-13_task-rsvp_events.csv: Found 40 entries for sub-13.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-14_task-rsvp_events.csv: Found 40 entries for sub-14.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-15_task-rsvp_events.csv: Found 40 entries for sub-15.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-16_task-rsvp_events.csv: Found 40 entries for sub-16.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-17_task-rsvp_events.csv: Found 40 entries for sub-17.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-18_task-rsvp_events.csv: Found 40 entries for sub-18.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-19_task-rsvp_events.csv: Found 40 entries for sub-19.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-20_task-rsvp_events.csv: Found 40 entries for sub-20.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-21_task-rsvp_events.csv: Found 40 entries for sub-21.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-22_task-rsvp_events.csv: Found 40 entries for sub-22.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-23_task-rsvp_events.csv: Found 40 entries for sub-23.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-24_task-rsvp_events.csv: Found 40 entries for sub-24.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-25_task-rsvp_events.csv: Found 40 entries for sub-25.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-26_task-rsvp_events.csv: Found 40 entries for sub-26.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-27_task-rsvp_events.csv: Found 40 entries for sub-27.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-28_task-rsvp_events.csv: Found 40 entries for sub-28.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-29_task-rsvp_events.csv: Found 40 entries for sub-29.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-30_task-rsvp_events.csv: Found 40 entries for sub-30.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-31_task-rsvp_events.csv: Found 40 entries for sub-31.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-32_task-rsvp_events.csv: Found 40 entries for sub-32.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-33_task-rsvp_events.csv: Found 40 entries for sub-33.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-34_task-rsvp_events.csv: Found 40 entries for sub-34.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-35_task-rsvp_events.csv: Found 40 entries for sub-35.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-36_task-rsvp_events.csv: Found 40 entries for sub-36.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-37_task-rsvp_events.csv: Found 40 entries for sub-37.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-38_task-rsvp_events.csv: Found 40 entries for sub-38.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-39_task-rsvp_events.csv: Found 40 entries for sub-39.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-40_task-rsvp_events.csv: Found 40 entries for sub-40.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-41_task-rsvp_events.csv: Found 40 entries for sub-41.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-42_task-rsvp_events.csv: Found 40 entries for sub-42.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-43_task-rsvp_events.csv: Found 40 entries for sub-43.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-44_task-rsvp_events.csv: Found 40 entries for sub-44.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-45_task-rsvp_events.csv: Found 40 entries for sub-45.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-46_task-rsvp_events.csv: Found 40 entries for sub-46.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-47_task-rsvp_events.csv: Found 40 entries for sub-47.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-48_task-rsvp_events.csv: Found 40 entries for sub-48.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-49_task-rsvp_events.csv: Found 40 entries for sub-49.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-50_task-rsvp_events.csv: Found 40 entries for sub-50.
#
# Total rows collected: 1960
#              stimname  time_stimon subject
# 0      hotdog_03s.jpg        70.65  sub-01
# 1     avocado_01b.jpg       142.30  sub-01
# 2      banana_03s.jpg       142.40  sub-01
# 3       apple_01b.jpg       188.79  sub-01
# 4  cheesecake_01s.jpg       194.89  sub-01
#               stimname  time_stimon subject  subject_num
# 0        apple_01b.jpg       188.79  sub-01            1
# 1        apple_02s.jpg      2467.60  sub-01            1
# 2        apple_03s.jpg      1789.92  sub-01            1
# 3        apple_04s.jpg      2863.86  sub-01            1
# 4      avocado_01b.jpg       142.30  sub-01            1
# 5      avocado_02s.jpg      2677.91  sub-01            1
# 6      avocado_03s.jpg      2090.69  sub-01            1
# 7      avocado_04s.jpg       988.93  sub-01            1
# 8       banana_01b.jpg      1551.74  sub-01            1
# 9       banana_02s.jpg      1322.62  sub-01            1
# 10      banana_03s.jpg       142.40  sub-01            1
# 11      banana_04s.jpg       591.12  sub-01            1
# 12        beet_01b.jpg      2616.92  sub-01            1
# 13        beet_02s.jpg       692.27  sub-01            1
# 14        beet_03s.jpg      2169.44  sub-01            1
# 15        beet_04s.jpg      2394.21  sub-01            1
# 16  cheesecake_01s.jpg       194.89  sub-01            1
# 17  cheesecake_02s.jpg       454.45  sub-01            1
# 18  cheesecake_03s.jpg      2809.03  sub-01            1
# 19  cheesecake_04s.jpg      2994.93  sub-01            1

# %%
# archivo final ALIMENTOS, activación del eeg
import numpy as np

# 1) Cargar todos los .set con glob
set_files = glob.glob(
    r"C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\*.set"
)

eeg_dict = {}  # subject → raw

for file_path in set_files:
    filename = os.path.basename(file_path)
    match = re.search(r"(sub-\d+)", filename)
    subject_id = match.group(1)
    
    print(f"Cargando EEG de {subject_id}...")
    raw = mne.io.read_raw_eeglab(file_path, preload=True)
    eeg_dict[subject_id] = raw


# 2) Extraer activación por evento
rows = []

for _, ev in alimentos_df.iterrows():
    subject = ev["subject"]
    t = ev["time_stimon"]

    if subject not in eeg_dict:
        print(f"⚠️ Advertencia: No hay EEG para {subject}")
        continue

    raw = eeg_dict[subject]
    
    data = raw.get_data()     # canales × tiempo
    times = raw.times         # vector de tiempos
    ch_names = raw.ch_names

    # índice más cercano al tiempo del evento
    idx = np.argmin(np.abs(times - t))
    
    # señal en ese instante (todos los canales)
    signal_at_t = data[:, idx]

    # armar fila final
    row = {
        "subject": subject,
        "stimname": ev["stimname"],
        "time_stimon": float(t),
        "time_eeg": float(times[idx])
    }

    for ch_name, value in zip(ch_names, signal_at_t):
        row[ch_name] = value

    rows.append(row)


# 3) DataFrame final
alimentos_eeg = pd.DataFrame(rows)

print("Activaciones extraídas:", alimentos_eeg.shape)
print(alimentos_eeg.head())
# Out:
# Cargando EEG de sub-01...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-01_task-rsvp_continuous.fdt
# Reading 0 ... 758934  =      0.000 ...  3035.736 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-02...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-02_task-rsvp_continuous.fdt
# Reading 0 ... 806819  =      0.000 ...  3227.276 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-03...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-03_task-rsvp_continuous.fdt
# Reading 0 ... 807259  =      0.000 ...  3229.036 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-04...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-04_task-rsvp_continuous.fdt
# Reading 0 ... 786239  =      0.000 ...  3144.956 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-05...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-05_task-rsvp_continuous.fdt
# Reading 0 ... 755504  =      0.000 ...  3022.016 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-06...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-06_task-rsvp_continuous.fdt
# Reading 0 ... 432024  =      0.000 ...  1728.096 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-07...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-07_task-rsvp_continuous.fdt
# Reading 0 ... 900154  =      0.000 ...  3600.616 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-08...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-08_task-rsvp_continuous.fdt
# Reading 0 ... 980544  =      0.000 ...  3922.176 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-09...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-09_task-rsvp_continuous.fdt
# Reading 0 ... 726364  =      0.000 ...  2905.456 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-10...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-10_task-rsvp_continuous.fdt
# Reading 0 ... 792019  =      0.000 ...  3168.076 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-11...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-11_task-rsvp_continuous.fdt
# Reading 0 ... 806514  =      0.000 ...  3226.056 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-12...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-12_task-rsvp_continuous.fdt
# Reading 0 ... 929119  =      0.000 ...  3716.476 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-13...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-13_task-rsvp_continuous.fdt
# Reading 0 ... 791274  =      0.000 ...  3165.096 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-14...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-14_task-rsvp_continuous.fdt
# Reading 0 ... 755894  =      0.000 ...  3023.576 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-15...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-15_task-rsvp_continuous.fdt
# Reading 0 ... 746674  =      0.000 ...  2986.696 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-16...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-16_task-rsvp_continuous.fdt
# Reading 0 ... 865704  =      0.000 ...  3462.816 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-17...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-17_task-rsvp_continuous.fdt
# Reading 0 ... 869194  =      0.000 ...  3476.776 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-18...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-18_task-rsvp_continuous.fdt
# Reading 0 ... 1046194  =      0.000 ...  4184.776 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-19...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-19_task-rsvp_continuous.fdt
# Reading 0 ... 770109  =      0.000 ...  3080.436 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-20...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-20_task-rsvp_continuous.fdt
# Reading 0 ... 1078519  =      0.000 ...  4314.076 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-21...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-21_task-rsvp_continuous.fdt
# Reading 0 ... 812749  =      0.000 ...  3250.996 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-22...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-22_task-rsvp_continuous.fdt
# Reading 0 ... 720179  =      0.000 ...  2880.716 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-23...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-23_task-rsvp_continuous.fdt
# Reading 0 ... 747184  =      0.000 ...  2988.736 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-24...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-24_task-rsvp_continuous.fdt
# Reading 0 ... 841814  =      0.000 ...  3367.256 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-25...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-25_task-rsvp_continuous.fdt
# Reading 0 ... 857104  =      0.000 ...  3428.416 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-26...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-26_task-rsvp_continuous.fdt
# Reading 0 ... 775939  =      0.000 ...  3103.756 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-27...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-27_task-rsvp_continuous.fdt
# Reading 0 ... 722469  =      0.000 ...  2889.876 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-28...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-28_task-rsvp_continuous.fdt
# Reading 0 ... 842579  =      0.000 ...  3370.316 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-29...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-29_task-rsvp_continuous.fdt
# Reading 0 ... 838224  =      0.000 ...  3352.896 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-30...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-30_task-rsvp_continuous.fdt
# Reading 0 ... 911304  =      0.000 ...  3645.216 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-31...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-31_task-rsvp_continuous.fdt
# Reading 0 ... 754544  =      0.000 ...  3018.176 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-32...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-32_task-rsvp_continuous.fdt
# Reading 0 ... 810274  =      0.000 ...  3241.096 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-33...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-33_task-rsvp_continuous.fdt
# Reading 0 ... 961614  =      0.000 ...  3846.456 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-34...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-34_task-rsvp_continuous.fdt
# Reading 0 ... 894089  =      0.000 ...  3576.356 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-35...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-35_task-rsvp_continuous.fdt
# Reading 0 ... 847754  =      0.000 ...  3391.016 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-36...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-36_task-rsvp_continuous.fdt
# Reading 0 ... 874169  =      0.000 ...  3496.676 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-37...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-37_task-rsvp_continuous.fdt
# Reading 0 ... 900154  =      0.000 ...  3600.616 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-38...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-38_task-rsvp_continuous.fdt
# Reading 0 ... 874619  =      0.000 ...  3498.476 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-39...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-39_task-rsvp_continuous.fdt
# Reading 0 ... 745199  =      0.000 ...  2980.796 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-40...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-40_task-rsvp_continuous.fdt
# Reading 0 ... 856339  =      0.000 ...  3425.356 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-41...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-41_task-rsvp_continuous.fdt
# Reading 0 ... 830879  =      0.000 ...  3323.516 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-42...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-42_task-rsvp_continuous.fdt
# Reading 0 ... 828159  =      0.000 ...  3312.636 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-43...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-43_task-rsvp_continuous.fdt
# Reading 0 ... 854259  =      0.000 ...  3417.036 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-44...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-44_task-rsvp_continuous.fdt
# Reading 0 ... 786699  =      0.000 ...  3146.796 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-45...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-45_task-rsvp_continuous.fdt
# Reading 0 ... 964449  =      0.000 ...  3857.796 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-46...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-46_task-rsvp_continuous.fdt
# Reading 0 ... 724429  =      0.000 ...  2897.716 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-47...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-47_task-rsvp_continuous.fdt
# Reading 0 ... 956949  =      0.000 ...  3827.796 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-48...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-48_task-rsvp_continuous.fdt
# Reading 0 ... 842494  =      0.000 ...  3369.976 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-49...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-49_task-rsvp_continuous.fdt
# Reading 0 ... 1090974  =      0.000 ...  4363.896 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-50...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-50_task-rsvp_continuous.fdt
# Reading 0 ... 817739  =      0.000 ...  3270.956 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\1156082522.py:17: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Activaciones extraídas: (1960, 68)
#   subject         stimname  time_stimon  time_eeg       Fp1        Fz  \
# 0  sub-01    apple_01b.jpg       188.79   188.788 -0.000237 -0.000036
# 1  sub-01    apple_02s.jpg      2467.60  2467.600 -0.000082 -0.000012
# 2  sub-01    apple_03s.jpg      1789.92  1789.920 -0.000039 -0.000009
# 3  sub-01    apple_04s.jpg      2863.86  2863.860 -0.000109  0.000008
# 4  sub-01  avocado_01b.jpg       142.30   142.300 -0.000014 -0.000007
#
#          F3        F7       FT9           FC5  ...        C6        C2  \
# 0 -0.000053 -0.000047  0.000041 -2.028935e-06  ...  0.000021  0.000018
# 1 -0.000018 -0.000018  0.000013  8.687915e-07  ... -0.000005  0.000016
# 2 -0.000011 -0.000020 -0.000002 -7.120968e-06  ...  0.000008 -0.000002
# 3 -0.000010 -0.000021  0.000014 -2.908330e-05  ...  0.000013  0.000018
# 4  0.000002  0.000004  0.000003  9.517220e-06  ... -0.000018 -0.000005
#
#         FC4           FT8            F6           AF8       AF4        F2  \
# 0  0.000003  2.746439e-05 -1.558637e-05 -1.171686e-04 -0.000064 -0.000024
# 1  0.000008  8.413367e-06 -2.334854e-06 -4.890660e-05 -0.000022 -0.000007
# 2  0.000003  1.139487e-05  2.498732e-06 -2.252891e-05 -0.000005  0.000001
# 3  0.000010  2.253450e-05  8.745576e-06 -5.328723e-05 -0.000029  0.000005
# 4 -0.000003 -1.725971e-08  7.696463e-07 -5.126191e-07 -0.000006 -0.000008
#
#             FCz            Cz
# 0 -8.113480e-07  1.948442e-05
# 1  9.162766e-06  2.027482e-05
# 2 -1.394021e-06  4.477309e-07
# 3  1.357906e-05  1.872813e-05
# 4 -4.778336e-06 -5.603971e-06
#
# [5 rows x 68 columns]

# %%
alimentos_eeg.to_csv("alimentos_eeg.csv", index=False, encoding="utf-8")
print("Archivo guardado como 'alimentos_eeg.csv'")
# Out:
# Archivo guardado como 'alimentos_eeg.csv'

# %% [markdown]
# # Datos animales

# %%
# animales

stimname_variables = ["alpaca_01b.jpg", "alpaca_02s.jpg", "alpaca_03s.jpg", "alpaca_04s.jpg",
                      "cat_01b.jpg", "cat_02s.jpg", "cat_03s.jpg", "cat_04s.jpg", 
                      "cheetah_01b.jpg", "cheetah_02s.jpg", "cheetah_03s.jpg", "cheetah_04s.jpg", 
                      "chipmunk_01b.jpg", "chipmunk_02n.jpg", "chipmunk_03n.jpg", "chipmunk_04n.jpg", 
                      "deer_01b.jpg", "deer_02s.jpg", "deer_03s.jpg", "deer_04s.jpg",
                      "eagle_01b.jpg", "eagle_02s.jpg", "eagle_03s.jpg", "eagle_04s.jpg", 
                      "elephant_01b.jpg", "elephant_02n.jpg", "elephant_03n.jpg", "elephant_04n.jpg",
                      "ferret_01b.jpg", "ferret_02s.jpg", "ferret_03s.jpg", "ferret_04s.jpg", 
                      "owl_01b.jpg", "owl_02s.jpg", "owl_03s.jpg", "owl_04s.jpg", 
                      "raccoon_01b.jpg", "raccoon_02s.jpg", "raccoon_03s.jpg", "raccoon_04n.jpg"


]

csv_files = glob.glob(r"C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-*_task-rsvp_events.csv")

resultados = []

for file_path in csv_files:
    try:
        df = pd.read_csv(file_path)

        # Extraer el nombre del archivo (ej: "sub-01_task-rsvp_events.csv")
        filename = os.path.basename(file_path)

        # Usar regex para sacar "sub-XX"
        match = re.search(r"(sub-\d+)", filename)
        subject_id = match.group(1) if match else "unknown"

        # Filtrar animales
        animales_df = df[df['stimname'].isin(stimname_variables)]

        # Seleccionar columnas
        selected = animales_df[['stimname', 'time_stimon']].copy()

        # Redondear
        selected['time_stimon'] = selected['time_stimon'].round(2)

        # Añadir columna del sujeto
        selected['subject'] = subject_id

        # Guardar
        resultados.append(selected)

        print(f"Processed {file_path}: Found {len(selected)} entries for {subject_id}.")

    except Exception as e:
        print(f"Error processing {file_path}: {e}")

# Concatenar
animales_df = pd.concat(resultados, ignore_index=True)

print("\nTotal rows collected:", len(animales_df))
print(animales_df.head())

# Crear columna numérica del sujeto
animales_df['subject_num'] = animales_df['subject'].str.extract(r'(\d+)').astype(int)

# Ordenar stimname según tu lista original
animales_df['stimname'] = pd.Categorical(
    animales_df['stimname'],
    categories=stimname_variables,
    ordered=True
)

# Orden final
animales_df = animales_df.sort_values(by=['subject_num', 'stimname']).reset_index(drop=True)

print(alimentos_df.head(20))
# Out:
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-01_task-rsvp_events.csv: Found 40 entries for sub-01.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-02_task-rsvp_events.csv: Found 40 entries for sub-02.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-03_task-rsvp_events.csv: Found 40 entries for sub-03.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-04_task-rsvp_events.csv: Found 40 entries for sub-04.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-05_task-rsvp_events.csv: Found 40 entries for sub-05.
# Error processing C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-06_task-rsvp_events.csv: 'stimname'
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-07_task-rsvp_events.csv: Found 40 entries for sub-07.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-08_task-rsvp_events.csv: Found 40 entries for sub-08.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-09_task-rsvp_events.csv: Found 40 entries for sub-09.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-10_task-rsvp_events.csv: Found 40 entries for sub-10.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-11_task-rsvp_events.csv: Found 40 entries for sub-11.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-12_task-rsvp_events.csv: Found 40 entries for sub-12.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-13_task-rsvp_events.csv: Found 40 entries for sub-13.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-14_task-rsvp_events.csv: Found 40 entries for sub-14.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-15_task-rsvp_events.csv: Found 40 entries for sub-15.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-16_task-rsvp_events.csv: Found 40 entries for sub-16.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-17_task-rsvp_events.csv: Found 40 entries for sub-17.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-18_task-rsvp_events.csv: Found 40 entries for sub-18.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-19_task-rsvp_events.csv: Found 40 entries for sub-19.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-20_task-rsvp_events.csv: Found 40 entries for sub-20.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-21_task-rsvp_events.csv: Found 40 entries for sub-21.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-22_task-rsvp_events.csv: Found 40 entries for sub-22.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-23_task-rsvp_events.csv: Found 40 entries for sub-23.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-24_task-rsvp_events.csv: Found 40 entries for sub-24.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-25_task-rsvp_events.csv: Found 40 entries for sub-25.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-26_task-rsvp_events.csv: Found 40 entries for sub-26.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-27_task-rsvp_events.csv: Found 40 entries for sub-27.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-28_task-rsvp_events.csv: Found 40 entries for sub-28.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-29_task-rsvp_events.csv: Found 40 entries for sub-29.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-30_task-rsvp_events.csv: Found 40 entries for sub-30.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-31_task-rsvp_events.csv: Found 40 entries for sub-31.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-32_task-rsvp_events.csv: Found 40 entries for sub-32.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-33_task-rsvp_events.csv: Found 40 entries for sub-33.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-34_task-rsvp_events.csv: Found 40 entries for sub-34.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-35_task-rsvp_events.csv: Found 40 entries for sub-35.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-36_task-rsvp_events.csv: Found 40 entries for sub-36.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-37_task-rsvp_events.csv: Found 40 entries for sub-37.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-38_task-rsvp_events.csv: Found 40 entries for sub-38.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-39_task-rsvp_events.csv: Found 40 entries for sub-39.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-40_task-rsvp_events.csv: Found 40 entries for sub-40.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-41_task-rsvp_events.csv: Found 40 entries for sub-41.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-42_task-rsvp_events.csv: Found 40 entries for sub-42.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-43_task-rsvp_events.csv: Found 40 entries for sub-43.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-44_task-rsvp_events.csv: Found 40 entries for sub-44.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-45_task-rsvp_events.csv: Found 40 entries for sub-45.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-46_task-rsvp_events.csv: Found 40 entries for sub-46.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-47_task-rsvp_events.csv: Found 40 entries for sub-47.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-48_task-rsvp_events.csv: Found 40 entries for sub-48.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-49_task-rsvp_events.csv: Found 40 entries for sub-49.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-50_task-rsvp_events.csv: Found 40 entries for sub-50.
#
# Total rows collected: 1960
#           stimname  time_stimon subject
# 0  raccoon_04n.jpg       163.12  sub-01
# 1   ferret_01b.jpg       173.97  sub-01
# 2     deer_03s.jpg       228.27  sub-01
# 3      owl_04s.jpg       235.97  sub-01
# 4  raccoon_01b.jpg       287.81  sub-01
#               stimname  time_stimon subject  subject_num
# 0        apple_01b.jpg       188.79  sub-01            1
# 1        apple_02s.jpg      2467.60  sub-01            1
# 2        apple_03s.jpg      1789.92  sub-01            1
# 3        apple_04s.jpg      2863.86  sub-01            1
# 4      avocado_01b.jpg       142.30  sub-01            1
# 5      avocado_02s.jpg      2677.91  sub-01            1
# 6      avocado_03s.jpg      2090.69  sub-01            1
# 7      avocado_04s.jpg       988.93  sub-01            1
# 8       banana_01b.jpg      1551.74  sub-01            1
# 9       banana_02s.jpg      1322.62  sub-01            1
# 10      banana_03s.jpg       142.40  sub-01            1
# 11      banana_04s.jpg       591.12  sub-01            1
# 12        beet_01b.jpg      2616.92  sub-01            1
# 13        beet_02s.jpg       692.27  sub-01            1
# 14        beet_03s.jpg      2169.44  sub-01            1
# 15        beet_04s.jpg      2394.21  sub-01            1
# 16  cheesecake_01s.jpg       194.89  sub-01            1
# 17  cheesecake_02s.jpg       454.45  sub-01            1
# 18  cheesecake_03s.jpg      2809.03  sub-01            1
# 19  cheesecake_04s.jpg      2994.93  sub-01            1

# %%
# archivo final ANIMALES, activación del eeg
import numpy as np

# 1) Cargar todos los .set con glob
eeg_dict = {}  # subject → raw

for file_path in set_files:
    filename = os.path.basename(file_path)
    match = re.search(r"(sub-\d+)", filename)
    subject_id = match.group(1)
    
    print(f"Cargando EEG de {subject_id}...")
    raw = mne.io.read_raw_eeglab(file_path, preload=True)
    eeg_dict[subject_id] = raw


# 2) Extraer activación por evento
rows = []

for _, ev in animales_df.iterrows():
    subject = ev["subject"]
    t = ev["time_stimon"]

    if subject not in eeg_dict:
        print(f"⚠️ Advertencia: No hay EEG para {subject}")
        continue

    raw = eeg_dict[subject]
    
    data = raw.get_data()     # canales × tiempo
    times = raw.times         # vector de tiempos
    ch_names = raw.ch_names

    # índice más cercano al tiempo del evento
    idx = np.argmin(np.abs(times - t))
    
    # señal en ese instante (todos los canales)
    signal_at_t = data[:, idx]

    # armar fila final
    row = {
        "subject": subject,
        "stimname": ev["stimname"],
        "time_stimon": float(t),
        "time_eeg": float(times[idx])
    }

    for ch_name, value in zip(ch_names, signal_at_t):
        row[ch_name] = value

    rows.append(row)


# 3) DataFrame final
animales_eeg = pd.DataFrame(rows)

print("Activaciones extraídas:", animales_eeg.shape)
print(animales_eeg.head())
# Out:
# Cargando EEG de sub-01...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-01_task-rsvp_continuous.fdt
# Reading 0 ... 758934  =      0.000 ...  3035.736 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-02...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-02_task-rsvp_continuous.fdt
# Reading 0 ... 806819  =      0.000 ...  3227.276 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-03...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-03_task-rsvp_continuous.fdt
# Reading 0 ... 807259  =      0.000 ...  3229.036 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-04...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-04_task-rsvp_continuous.fdt
# Reading 0 ... 786239  =      0.000 ...  3144.956 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-05...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-05_task-rsvp_continuous.fdt
# Reading 0 ... 755504  =      0.000 ...  3022.016 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-06...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-06_task-rsvp_continuous.fdt
# Reading 0 ... 432024  =      0.000 ...  1728.096 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-07...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-07_task-rsvp_continuous.fdt
# Reading 0 ... 900154  =      0.000 ...  3600.616 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-08...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-08_task-rsvp_continuous.fdt
# Reading 0 ... 980544  =      0.000 ...  3922.176 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-09...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-09_task-rsvp_continuous.fdt
# Reading 0 ... 726364  =      0.000 ...  2905.456 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-10...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-10_task-rsvp_continuous.fdt
# Reading 0 ... 792019  =      0.000 ...  3168.076 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-11...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-11_task-rsvp_continuous.fdt
# Reading 0 ... 806514  =      0.000 ...  3226.056 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-12...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-12_task-rsvp_continuous.fdt
# Reading 0 ... 929119  =      0.000 ...  3716.476 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-13...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-13_task-rsvp_continuous.fdt
# Reading 0 ... 791274  =      0.000 ...  3165.096 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-14...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-14_task-rsvp_continuous.fdt
# Reading 0 ... 755894  =      0.000 ...  3023.576 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-15...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-15_task-rsvp_continuous.fdt
# Reading 0 ... 746674  =      0.000 ...  2986.696 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-16...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-16_task-rsvp_continuous.fdt
# Reading 0 ... 865704  =      0.000 ...  3462.816 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-17...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-17_task-rsvp_continuous.fdt
# Reading 0 ... 869194  =      0.000 ...  3476.776 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-18...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-18_task-rsvp_continuous.fdt
# Reading 0 ... 1046194  =      0.000 ...  4184.776 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-19...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-19_task-rsvp_continuous.fdt
# Reading 0 ... 770109  =      0.000 ...  3080.436 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-20...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-20_task-rsvp_continuous.fdt
# Reading 0 ... 1078519  =      0.000 ...  4314.076 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-21...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-21_task-rsvp_continuous.fdt
# Reading 0 ... 812749  =      0.000 ...  3250.996 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-22...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-22_task-rsvp_continuous.fdt
# Reading 0 ... 720179  =      0.000 ...  2880.716 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-23...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-23_task-rsvp_continuous.fdt
# Reading 0 ... 747184  =      0.000 ...  2988.736 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-24...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-24_task-rsvp_continuous.fdt
# Reading 0 ... 841814  =      0.000 ...  3367.256 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-25...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-25_task-rsvp_continuous.fdt
# Reading 0 ... 857104  =      0.000 ...  3428.416 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-26...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-26_task-rsvp_continuous.fdt
# Reading 0 ... 775939  =      0.000 ...  3103.756 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-27...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-27_task-rsvp_continuous.fdt
# Reading 0 ... 722469  =      0.000 ...  2889.876 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-28...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-28_task-rsvp_continuous.fdt
# Reading 0 ... 842579  =      0.000 ...  3370.316 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-29...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-29_task-rsvp_continuous.fdt
# Reading 0 ... 838224  =      0.000 ...  3352.896 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-30...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-30_task-rsvp_continuous.fdt
# Reading 0 ... 911304  =      0.000 ...  3645.216 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-31...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-31_task-rsvp_continuous.fdt
# Reading 0 ... 754544  =      0.000 ...  3018.176 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-32...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-32_task-rsvp_continuous.fdt
# Reading 0 ... 810274  =      0.000 ...  3241.096 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-33...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-33_task-rsvp_continuous.fdt
# Reading 0 ... 961614  =      0.000 ...  3846.456 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-34...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-34_task-rsvp_continuous.fdt
# Reading 0 ... 894089  =      0.000 ...  3576.356 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-35...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-35_task-rsvp_continuous.fdt
# Reading 0 ... 847754  =      0.000 ...  3391.016 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-36...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-36_task-rsvp_continuous.fdt
# Reading 0 ... 874169  =      0.000 ...  3496.676 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-37...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-37_task-rsvp_continuous.fdt
# Reading 0 ... 900154  =      0.000 ...  3600.616 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-38...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-38_task-rsvp_continuous.fdt
# Reading 0 ... 874619  =      0.000 ...  3498.476 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-39...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-39_task-rsvp_continuous.fdt
# Reading 0 ... 745199  =      0.000 ...  2980.796 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-40...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-40_task-rsvp_continuous.fdt
# Reading 0 ... 856339  =      0.000 ...  3425.356 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-41...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-41_task-rsvp_continuous.fdt
# Reading 0 ... 830879  =      0.000 ...  3323.516 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-42...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-42_task-rsvp_continuous.fdt
# Reading 0 ... 828159  =      0.000 ...  3312.636 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-43...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-43_task-rsvp_continuous.fdt
# Reading 0 ... 854259  =      0.000 ...  3417.036 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-44...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-44_task-rsvp_continuous.fdt
# Reading 0 ... 786699  =      0.000 ...  3146.796 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-45...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-45_task-rsvp_continuous.fdt
# Reading 0 ... 964449  =      0.000 ...  3857.796 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-46...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-46_task-rsvp_continuous.fdt
# Reading 0 ... 724429  =      0.000 ...  2897.716 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-47...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-47_task-rsvp_continuous.fdt
# Reading 0 ... 956949  =      0.000 ...  3827.796 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-48...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-48_task-rsvp_continuous.fdt
# Reading 0 ... 842494  =      0.000 ...  3369.976 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-49...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-49_task-rsvp_continuous.fdt
# Reading 0 ... 1090974  =      0.000 ...  4363.896 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-50...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-50_task-rsvp_continuous.fdt
# Reading 0 ... 817739  =      0.000 ...  3270.956 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\3546509979.py:13: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Activaciones extraídas: (1960, 68)
#   subject        stimname  time_stimon  time_eeg       Fp1        Fz  \
# 0  sub-01  alpaca_01b.jpg      1945.97  1945.968 -0.000165 -0.000019
# 1  sub-01  alpaca_02s.jpg       518.13   518.128 -0.000113 -0.000015
# 2  sub-01  alpaca_03s.jpg      3054.67  3035.736 -0.000085  0.000004
# 3  sub-01  alpaca_04s.jpg       585.82   585.820  0.000456  0.000039
# 4  sub-01     cat_01b.jpg       605.83   605.832  0.000009 -0.000003
#
#          F3        F7       FT9       FC5  ...            C6        C2  \
# 0 -0.000026 -0.000057  0.000001 -0.000006  ...  1.675366e-05  0.000019
# 1 -0.000014 -0.000019  0.000009  0.000005  ...  2.093468e-05  0.000005
# 2 -0.000040 -0.000096 -0.000055 -0.000033  ...  1.779714e-05  0.000009
# 3  0.000074  0.000111 -0.000060 -0.000007  ... -8.509542e-05 -0.000027
# 4  0.000012  0.000005  0.000010  0.000004  ...  3.655281e-08 -0.000010
#
#         FC4       FT8        F6           AF8       AF4        F2       FCz  \
# 0  0.000007  0.000002 -0.000023 -1.074777e-04 -0.000067 -0.000013  0.000006
# 1  0.000003  0.000012 -0.000007 -5.991528e-05 -0.000042 -0.000015  0.000007
# 2  0.000023  0.000055  0.000048  5.635645e-05  0.000011  0.000013  0.000006
# 3 -0.000027 -0.000069  0.000021  2.566330e-04  0.000130  0.000028 -0.000011
# 4 -0.000010  0.000012  0.000002 -9.352502e-07 -0.000001 -0.000008 -0.000015
#
#          Cz
# 0  0.000018
# 1  0.000012
# 2  0.000007
# 3 -0.000029
# 4 -0.000007
#
# [5 rows x 68 columns]

# %%
animales_eeg.to_csv("animales_eeg.csv", index=False, encoding="utf-8")
print("Archivo guardado como 'animales_eeg.csv'")
# Out:
# Archivo guardado como 'animales_eeg.csv'

# %% [markdown]
# # Datos herramientas

# %%
# herramientas

stimname_variables = ["axe_01b.jpg", "axe_02n.jpg", "axe_03n.jpg", "axe_04n.jpg", 
                      "chainsaw_01b.jpg", "chainsaw_02s.jpg", "chainsaw_03s.jpg", "chainsaw_04s.jpg", 
                      "compass_01b.jpg", "compass_02s.jpg", "compass_03s.jpg", "compass_04s.jpg", 
                      "corkscrew_01b.jpg", "corkscrew_02s.jpg", "corkscrew_03s.jpg", "corkscrew_04s.jpg", 
                      "crayon_01b.jpg", "crayon_02s.jpg", "crayon_03s.jpg", "crayon_04s.jpg",
                      "eraser_01s.jpg", "eraser_02s.jpg", "eraser_03s.jpg", "eraser_04s.jpg",
                      "hammer_01b.jpg", "hammer_02s.jpg", "hammer_03s.jpg", "hammer_04s.jpg",
                      "jackhammer_01b.jpg", "jackhammer_02s.jpg", "jackhammer_03s.jpg", "jackhammer_04s.jpg", 
                      "key_01b.jpg", "key_02s.jpg", "key_03s.jpg", "key_04s.jpg", 
                      "paperclip_01s.jpg", "paperclip_02s.jpg", "paperclip_03s.jpg", "paperclip_04s.jpg"



]

csv_files = glob.glob(r"C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-*_task-rsvp_events.csv")

resultados = []

for file_path in csv_files:
    try:
        df = pd.read_csv(file_path)

        # Extraer el nombre del archivo (ej: "sub-01_task-rsvp_events.csv")
        filename = os.path.basename(file_path)

        # Usar regex para sacar "sub-XX"
        match = re.search(r"(sub-\d+)", filename)
        subject_id = match.group(1) if match else "unknown"

        # Filtrar herramientas
        herramientas_df = df[df['stimname'].isin(stimname_variables)]

        # Seleccionar columnas
        selected = herramientas_df[['stimname', 'time_stimon']].copy()

        # Redondear
        selected['time_stimon'] = selected['time_stimon'].round(2)

        # Añadir columna del sujeto
        selected['subject'] = subject_id

        # Guardar
        resultados.append(selected)

        print(f"Processed {file_path}: Found {len(selected)} entries for {subject_id}.")

    except Exception as e:
        print(f"Error processing {file_path}: {e}")

# Concatenar
herramientas_df = pd.concat(resultados, ignore_index=True)

print("\nTotal rows collected:", herramientas_df)
print(herramientas_df.head())

# Crear columna numérica del sujeto
herramientas_df['subject_num'] = herramientas_df['subject'].str.extract(r'(\d+)').astype(int)

# Ordenar stimname según tu lista original
herramientas_df['stimname'] = pd.Categorical(
    herramientas_df['stimname'],
    categories=stimname_variables,
    ordered=True
)

# Orden final
herramientas_df = herramientas_df.sort_values(by=['subject_num', 'stimname']).reset_index(drop=True)

print(alimentos_df.head(20))
# Out:
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-01_task-rsvp_events.csv: Found 40 entries for sub-01.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-02_task-rsvp_events.csv: Found 40 entries for sub-02.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-03_task-rsvp_events.csv: Found 40 entries for sub-03.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-04_task-rsvp_events.csv: Found 40 entries for sub-04.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-05_task-rsvp_events.csv: Found 40 entries for sub-05.
# Error processing C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-06_task-rsvp_events.csv: 'stimname'
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-07_task-rsvp_events.csv: Found 40 entries for sub-07.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-08_task-rsvp_events.csv: Found 40 entries for sub-08.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-09_task-rsvp_events.csv: Found 40 entries for sub-09.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-10_task-rsvp_events.csv: Found 40 entries for sub-10.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-11_task-rsvp_events.csv: Found 40 entries for sub-11.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-12_task-rsvp_events.csv: Found 40 entries for sub-12.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-13_task-rsvp_events.csv: Found 40 entries for sub-13.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-14_task-rsvp_events.csv: Found 40 entries for sub-14.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-15_task-rsvp_events.csv: Found 40 entries for sub-15.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-16_task-rsvp_events.csv: Found 40 entries for sub-16.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-17_task-rsvp_events.csv: Found 40 entries for sub-17.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-18_task-rsvp_events.csv: Found 40 entries for sub-18.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-19_task-rsvp_events.csv: Found 40 entries for sub-19.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-20_task-rsvp_events.csv: Found 40 entries for sub-20.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-21_task-rsvp_events.csv: Found 40 entries for sub-21.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-22_task-rsvp_events.csv: Found 40 entries for sub-22.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-23_task-rsvp_events.csv: Found 40 entries for sub-23.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-24_task-rsvp_events.csv: Found 40 entries for sub-24.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-25_task-rsvp_events.csv: Found 40 entries for sub-25.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-26_task-rsvp_events.csv: Found 40 entries for sub-26.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-27_task-rsvp_events.csv: Found 40 entries for sub-27.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-28_task-rsvp_events.csv: Found 40 entries for sub-28.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-29_task-rsvp_events.csv: Found 40 entries for sub-29.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-30_task-rsvp_events.csv: Found 40 entries for sub-30.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-31_task-rsvp_events.csv: Found 40 entries for sub-31.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-32_task-rsvp_events.csv: Found 40 entries for sub-32.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-33_task-rsvp_events.csv: Found 40 entries for sub-33.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-34_task-rsvp_events.csv: Found 40 entries for sub-34.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-35_task-rsvp_events.csv: Found 40 entries for sub-35.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-36_task-rsvp_events.csv: Found 40 entries for sub-36.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-37_task-rsvp_events.csv: Found 40 entries for sub-37.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-38_task-rsvp_events.csv: Found 40 entries for sub-38.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-39_task-rsvp_events.csv: Found 40 entries for sub-39.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-40_task-rsvp_events.csv: Found 40 entries for sub-40.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-41_task-rsvp_events.csv: Found 40 entries for sub-41.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-42_task-rsvp_events.csv: Found 40 entries for sub-42.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-43_task-rsvp_events.csv: Found 40 entries for sub-43.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-44_task-rsvp_events.csv: Found 40 entries for sub-44.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-45_task-rsvp_events.csv: Found 40 entries for sub-45.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-46_task-rsvp_events.csv: Found 40 entries for sub-46.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-47_task-rsvp_events.csv: Found 40 entries for sub-47.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-48_task-rsvp_events.csv: Found 40 entries for sub-48.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-49_task-rsvp_events.csv: Found 40 entries for sub-49.
# Processed C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\Eventos\sub-50_task-rsvp_events.csv: Found 40 entries for sub-50.
#
# Total rows collected:                 stimname  time_stimon subject
# 0       chainsaw_02s.jpg        87.05  sub-01
# 1     jackhammer_04s.jpg       148.30  sub-01
# 2         crayon_01b.jpg       186.57  sub-01
# 3            key_02s.jpg       191.09  sub-01
# 4       chainsaw_03s.jpg       307.71  sub-01
# ...                  ...          ...     ...
# 1955      hammer_01b.jpg      2653.94  sub-50
# 1956  jackhammer_04s.jpg      2751.61  sub-50
# 1957     compass_02s.jpg      2775.88  sub-50
# 1958      crayon_01b.jpg      2885.95  sub-50
# 1959   corkscrew_01b.jpg      2945.55  sub-50
#
# [1960 rows x 3 columns]
#              stimname  time_stimon subject
# 0    chainsaw_02s.jpg        87.05  sub-01
# 1  jackhammer_04s.jpg       148.30  sub-01
# 2      crayon_01b.jpg       186.57  sub-01
# 3         key_02s.jpg       191.09  sub-01
# 4    chainsaw_03s.jpg       307.71  sub-01
#               stimname  time_stimon subject  subject_num
# 0        apple_01b.jpg       188.79  sub-01            1
# 1        apple_02s.jpg      2467.60  sub-01            1
# 2        apple_03s.jpg      1789.92  sub-01            1
# 3        apple_04s.jpg      2863.86  sub-01            1
# 4      avocado_01b.jpg       142.30  sub-01            1
# 5      avocado_02s.jpg      2677.91  sub-01            1
# 6      avocado_03s.jpg      2090.69  sub-01            1
# 7      avocado_04s.jpg       988.93  sub-01            1
# 8       banana_01b.jpg      1551.74  sub-01            1
# 9       banana_02s.jpg      1322.62  sub-01            1
# 10      banana_03s.jpg       142.40  sub-01            1
# 11      banana_04s.jpg       591.12  sub-01            1
# 12        beet_01b.jpg      2616.92  sub-01            1
# 13        beet_02s.jpg       692.27  sub-01            1
# 14        beet_03s.jpg      2169.44  sub-01            1
# 15        beet_04s.jpg      2394.21  sub-01            1
# 16  cheesecake_01s.jpg       194.89  sub-01            1
# 17  cheesecake_02s.jpg       454.45  sub-01            1
# 18  cheesecake_03s.jpg      2809.03  sub-01            1
# 19  cheesecake_04s.jpg      2994.93  sub-01            1

# %%
# archivo final HERRAMIENTAS, activación del eeg
import numpy as np

# 1) Cargar todos los .set con glob
#set_files = glob.glob(
 #   r"C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\*.set")

eeg_dict = {}  # subject → raw

for file_path in set_files:
    filename = os.path.basename(file_path)
    match = re.search(r"(sub-\d+)", filename)
    subject_id = match.group(1)
    
    print(f"Cargando EEG de {subject_id}...")
    raw = mne.io.read_raw_eeglab(file_path, preload=True)
    eeg_dict[subject_id] = raw


# 2) Extraer activación por evento
rows = []

for _, ev in herramientas_df.iterrows():
    subject = ev["subject"]
    t = ev["time_stimon"]

    if subject not in eeg_dict:
        print(f"⚠️ Advertencia: No hay EEG para {subject}")
        continue

    raw = eeg_dict[subject]
    
    data = raw.get_data()     # canales × tiempo
    times = raw.times         # vector de tiempos
    ch_names = raw.ch_names

    # índice más cercano al tiempo del evento
    idx = np.argmin(np.abs(times - t))
    
    # señal en ese instante (todos los canales)
    signal_at_t = data[:, idx]

    # armar fila final
    row = {
        "subject": subject,
        "stimname": ev["stimname"],
        "time_stimon": float(t),
        "time_eeg": float(times[idx])
    }

    for ch_name, value in zip(ch_names, signal_at_t):
        row[ch_name] = value

    rows.append(row)


# 3) DataFrame final
herramientas_eeg = pd.DataFrame(rows)

print("Activaciones extraídas:", herramientas_eeg.shape)
print(herramientas_eeg.head())
# Out:
# Cargando EEG de sub-01...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-01_task-rsvp_continuous.fdt
# Reading 0 ... 758934  =      0.000 ...  3035.736 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-02...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-02_task-rsvp_continuous.fdt
# Reading 0 ... 806819  =      0.000 ...  3227.276 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-03...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-03_task-rsvp_continuous.fdt
# Reading 0 ... 807259  =      0.000 ...  3229.036 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-04...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-04_task-rsvp_continuous.fdt
# Reading 0 ... 786239  =      0.000 ...  3144.956 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-05...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-05_task-rsvp_continuous.fdt
# Reading 0 ... 755504  =      0.000 ...  3022.016 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-06...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-06_task-rsvp_continuous.fdt
# Reading 0 ... 432024  =      0.000 ...  1728.096 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-07...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-07_task-rsvp_continuous.fdt
# Reading 0 ... 900154  =      0.000 ...  3600.616 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-08...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-08_task-rsvp_continuous.fdt
# Reading 0 ... 980544  =      0.000 ...  3922.176 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-09...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-09_task-rsvp_continuous.fdt
# Reading 0 ... 726364  =      0.000 ...  2905.456 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-10...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-10_task-rsvp_continuous.fdt
# Reading 0 ... 792019  =      0.000 ...  3168.076 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-11...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-11_task-rsvp_continuous.fdt
# Reading 0 ... 806514  =      0.000 ...  3226.056 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-12...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-12_task-rsvp_continuous.fdt
# Reading 0 ... 929119  =      0.000 ...  3716.476 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-13...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-13_task-rsvp_continuous.fdt
# Reading 0 ... 791274  =      0.000 ...  3165.096 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-14...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-14_task-rsvp_continuous.fdt
# Reading 0 ... 755894  =      0.000 ...  3023.576 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-15...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-15_task-rsvp_continuous.fdt
# Reading 0 ... 746674  =      0.000 ...  2986.696 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-16...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-16_task-rsvp_continuous.fdt
# Reading 0 ... 865704  =      0.000 ...  3462.816 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-17...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-17_task-rsvp_continuous.fdt
# Reading 0 ... 869194  =      0.000 ...  3476.776 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-18...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-18_task-rsvp_continuous.fdt
# Reading 0 ... 1046194  =      0.000 ...  4184.776 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-19...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-19_task-rsvp_continuous.fdt
# Reading 0 ... 770109  =      0.000 ...  3080.436 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-20...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-20_task-rsvp_continuous.fdt
# Reading 0 ... 1078519  =      0.000 ...  4314.076 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-21...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-21_task-rsvp_continuous.fdt
# Reading 0 ... 812749  =      0.000 ...  3250.996 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-22...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-22_task-rsvp_continuous.fdt
# Reading 0 ... 720179  =      0.000 ...  2880.716 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-23...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-23_task-rsvp_continuous.fdt
# Reading 0 ... 747184  =      0.000 ...  2988.736 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-24...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-24_task-rsvp_continuous.fdt
# Reading 0 ... 841814  =      0.000 ...  3367.256 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-25...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-25_task-rsvp_continuous.fdt
# Reading 0 ... 857104  =      0.000 ...  3428.416 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-26...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-26_task-rsvp_continuous.fdt
# Reading 0 ... 775939  =      0.000 ...  3103.756 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-27...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-27_task-rsvp_continuous.fdt
# Reading 0 ... 722469  =      0.000 ...  2889.876 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-28...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-28_task-rsvp_continuous.fdt
# Reading 0 ... 842579  =      0.000 ...  3370.316 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-29...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-29_task-rsvp_continuous.fdt
# Reading 0 ... 838224  =      0.000 ...  3352.896 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-30...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-30_task-rsvp_continuous.fdt
# Reading 0 ... 911304  =      0.000 ...  3645.216 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-31...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-31_task-rsvp_continuous.fdt
# Reading 0 ... 754544  =      0.000 ...  3018.176 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-32...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-32_task-rsvp_continuous.fdt
# Reading 0 ... 810274  =      0.000 ...  3241.096 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-33...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-33_task-rsvp_continuous.fdt
# Reading 0 ... 961614  =      0.000 ...  3846.456 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-34...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-34_task-rsvp_continuous.fdt
# Reading 0 ... 894089  =      0.000 ...  3576.356 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-35...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-35_task-rsvp_continuous.fdt
# Reading 0 ... 847754  =      0.000 ...  3391.016 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-36...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-36_task-rsvp_continuous.fdt
# Reading 0 ... 874169  =      0.000 ...  3496.676 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-37...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-37_task-rsvp_continuous.fdt
# Reading 0 ... 900154  =      0.000 ...  3600.616 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-38...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-38_task-rsvp_continuous.fdt
# Reading 0 ... 874619  =      0.000 ...  3498.476 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-39...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-39_task-rsvp_continuous.fdt
# Reading 0 ... 745199  =      0.000 ...  2980.796 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-40...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-40_task-rsvp_continuous.fdt
# Reading 0 ... 856339  =      0.000 ...  3425.356 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-41...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-41_task-rsvp_continuous.fdt
# Reading 0 ... 830879  =      0.000 ...  3323.516 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-42...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-42_task-rsvp_continuous.fdt
# Reading 0 ... 828159  =      0.000 ...  3312.636 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-43...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-43_task-rsvp_continuous.fdt
# Reading 0 ... 854259  =      0.000 ...  3417.036 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-44...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-44_task-rsvp_continuous.fdt
# Reading 0 ... 786699  =      0.000 ...  3146.796 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-45...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-45_task-rsvp_continuous.fdt
# Reading 0 ... 964449  =      0.000 ...  3857.796 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-46...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-46_task-rsvp_continuous.fdt
# Reading 0 ... 724429  =      0.000 ...  2897.716 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-47...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-47_task-rsvp_continuous.fdt
# Reading 0 ... 956949  =      0.000 ...  3827.796 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-48...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-48_task-rsvp_continuous.fdt
# Reading 0 ... 842494  =      0.000 ...  3369.976 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: Estimated head radius (23.1 cm) is above the 99th percentile for adult head size. Check if the montage_units argument is correct (the default is "mm", but your channel positions may be in different units).
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-49...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-49_task-rsvp_continuous.fdt
# Reading 0 ... 1090974  =      0.000 ...  4363.896 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Cargando EEG de sub-50...
# Reading C:\Users\marub\OneDrive\Escritorio\Datos proyecto modelos I\EEG\sub-50_task-rsvp_continuous.fdt
# Reading 0 ... 817739  =      0.000 ...  3270.956 secs...
# C:\Users\marub\AppData\Local\Temp\ipykernel_21600\564706102.py:16: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(file_path, preload=True)
# Activaciones extraídas: (1960, 68)
#   subject          stimname  time_stimon  time_eeg       Fp1            Fz  \
# 0  sub-01       axe_01b.jpg      1413.44  1413.440 -0.000064  6.281501e-08
# 1  sub-01       axe_02n.jpg      2375.51  2375.512  0.000037  1.095241e-06
# 2  sub-01       axe_03n.jpg      2798.73  2798.728 -0.000043  6.051934e-06
# 3  sub-01       axe_04n.jpg      2212.91  2212.908 -0.000354 -4.150097e-05
# 4  sub-01  chainsaw_01b.jpg      1793.92  1793.920 -0.000207 -2.468630e-05
#
#          F3        F7           FT9       FC5  ...        C6        C2  \
# 0 -0.000016 -0.000014  8.869621e-06 -0.000002  ...  0.000006  0.000011
# 1  0.000002 -0.000006 -2.033685e-05 -0.000006  ... -0.000012 -0.000005
# 2 -0.000013 -0.000022 -1.659148e-07 -0.000010  ...  0.000002  0.000015
# 3 -0.000076 -0.000064  6.449582e-05 -0.000010  ...  0.000052  0.000031
# 4 -0.000056 -0.000053  1.930429e-05 -0.000014  ...  0.000029  0.000021
#
#         FC4       FT8            F6       AF8       AF4        F2       FCz  \
# 0  0.000005  0.000008 -9.174306e-06 -0.000032 -0.000030 -0.000004  0.000015
# 1 -0.000004 -0.000013 -9.966000e-07  0.000013  0.000005  0.000004  0.000002
# 2  0.000006 -0.000006 -6.849342e-06 -0.000030 -0.000003  0.000003  0.000005
# 3  0.000008  0.000025 -3.624107e-05 -0.000214 -0.000105 -0.000031  0.000004
# 4  0.000004  0.000028 -1.368336e-05 -0.000086 -0.000064 -0.000019 -0.000002
#
#              Cz
# 0  1.000123e-05
# 1 -5.277166e-07
# 2  9.447508e-06
# 3  2.708586e-05
# 4  1.716239e-05
#
# [5 rows x 68 columns]

# %%
herramientas_eeg.to_csv("herramientas_eeg.csv", index=False, encoding="utf-8")
print("Archivo guardado como 'herramientas_eeg.csv'")
# Out:
# Archivo guardado como 'herramientas_eeg.csv'
