# %%
import networkx as nx

# %%
import matplotlib.pyplot as plt

# %%
G = nx.Graph()

# %%
G.nodes(), G.edges()
# Out:
# (NodeView(()), EdgeView([]))

# %%
G.add_nodes_from(["A", "B", "C", "D", "E"])

# %%
G.nodes(), G.edges()
# Out:
# (NodeView(('A', 'B', 'C', 'D', 'E')), EdgeView([]))

# %%
G.add_edges_from([ ("B", "C"), ("C", "A"), ("D", "E")]) #Agregar aristas

# %%
G.add_edge("C", "D")
nx.draw_networkx(G)

# %%
nx.draw_spring(G)
