# %% [markdown]
# # Paquete NumPy

# %%
import numpy as np # Llamamos NumPy como np

# %%
np.random.rand()
# Out:
# 0.3922893856027765

# %%
np.random.rand(6, 2)
# Out:
# array([[0.65772096, 0.98781881],
#        [0.12940785, 0.06968219],
#        [0.23002859, 0.56121812],
#        [0.92285948, 0.15894324],
#        [0.92745921, 0.79727934],
#        [0.63145762, 0.81972747]])

# %%
np.random.uniform()
# Out:
# 0.5465332388278256

# %%
np.random.uniform(size = [3, 4])
# Out:
# array([[0.33270433, 0.33656392, 0.59524225, 0.36440141],
#        [0.21533783, 0.57012968, 0.39806424, 0.61068078],
#        [0.10851165, 0.22885608, 0.23610426, 0.92077815]])

# %%
a, b = 10, 15
np.random.uniform(a, b, size = [3, 4])
# Out:
# array([[12.32636966, 10.65400874, 11.86657271, 14.71414167],
#        [12.46026104, 14.16133988, 14.9446158 , 14.70970829],
#        [14.87690113, 14.56242491, 13.50645498, 10.67912266]])

# %%
np.random.randint(10, size = [22])
# Out:
# array([0, 0, 8, 7, 2, 1, 9, 3, 1, 0, 7, 6, 5, 5, 1, 6, 0, 0, 6, 9, 5, 6],
#       dtype=int32)

# %%
np.random.normal()
# Out:
# 0.4086756031220514

# %%
mu, sigma = -8, 4
np.random.normal(mu, sigma, size = [2, 6])
# Out:
# array([[ -7.18239189,  -5.82914523,  -8.22715308,  -6.52737841,
#         -13.33127608,  -6.83257159],
#        [ -6.05136795,  -4.58365065, -10.84366874,  -6.68814043,
#          -3.69455   , -13.61381284]])

# %%
valores = np.random.normal(0, 1, size = 100000)
np.mean(valores), np.std(valores)
# Out:
# (np.float64(-0.0006382445800543417), np.float64(1.0051340017961852))

# %%
vec1, vec2 = np.array([2, 3, 4]), np.array([-1, -10, 0])
np.vdot(vec1, vec2)
# Out:
# np.int64(-32)

# %%
vec2.sort()
vec2[::-1]
# Out:
# array([  0,  -1, -10])

# %% [markdown]
# # Paquete MatPlotLib

# %%
import matplotlib.pyplot as plt # Llamamos MatPlotLib como plt

# %%
valores = np.arange(20) 
plt.plot(valores, ".")

# %%
valores = np.random.uniform(size = 5) # No es uniforme porque tenemos pocos ensayos
plt.hist(valores)
# Out:
# (array([2., 0., 1., 0., 0., 0., 0., 1., 0., 1.]),
#  array([0.06135313, 0.15124464, 0.24113615, 0.33102766, 0.42091917,
#         0.51081068, 0.6007022 , 0.69059371, 0.78048522, 0.87037673,
#         0.96026824]),
#  <BarContainer object of 10 artists>)

# %%
valores
# Out:
# array([0.14391741, 0.75352306, 0.06135313, 0.2610729 , 0.96026824])

# %%
# Ejercicio: Crear una arreglo de números random con distribución normal de tamaño 100,000, donde media-mu = 0 y sd = 1 
# Plotear el histograma
valores = np.random.normal(0, 1, size = 100000)
plt.hist(valores, bins = 100); # bins se refiere al número de rectángulos
# ; es para no imprimir algo 
# ↑ sd = ↑ ancho de curva; mu simplemente recorre sobre el eje X

# %% [markdown]
# # Paquete Pandas
# Hace series y dataframes.

# %%
import pandas as pd # Llamamos Pandas como pd

# %%
pd.Series([4, 5, 6, 7, 8, 9, "casa"])
# Identifica los tipos de datos, si se tienen diferentes, los marcará como "object"
# Out:
# 0       4
# 1       5
# 2       6
# 3       7
# 4       8
# 5       9
# 6    casa
# dtype: object

# %%
# Podemos escoger la forma en la que se nos presenta el índice:
pd.Series(range(50, 56), index = ['a', 'b', 'c', 'd', 'e', 'f'])
# Out:
# a    50
# b    51
# c    52
# d    53
# e    54
# f    55
# dtype: int64

# %%
serie = pd.Series([5, 6, 7, 8, 9]), index =  ['a', 'b', 'c', 'd', 'e']
serie['b'] 
# La indexación en series es diferente de listas: en series, no aplica [-i]
# Out:
#   Cell In[50], line 1
#     serie = pd.Series([5, 6, 7, 8, 9]), index =  ['a', 'b', 'c', 'd', 'e']
#     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?
