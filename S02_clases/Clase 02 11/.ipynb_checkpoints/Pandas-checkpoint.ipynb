# %%
import numpy as np

# %%
np.random.randint(10, size=[8])
# Out:
# array([2, 0, 4, 6, 6, 3, 5, 0], dtype=int32)

# %%
np.random.normal()
# Out:
# 1.1774797987553864

# %%
mu, sigma= -8,4
np.random.normal(mu, sigma, size=[2, 6])
# Out:
# array([[-7.41448486e+00, -1.25659587e+01, -1.10116669e+01,
#         -8.77125186e+00, -1.19133745e+01, -7.24821531e-03],
#        [-7.27124189e+00, -7.72357620e+00, -1.03310962e+01,
#         -8.08896657e+00, -4.65094269e+00, -1.24338717e+01]])

# %%
valores= np.random.normal(0,1, size=100000000)
np.mean(valores), np.std(valores)
# Out:
# (np.float64(-4.178065568629614e-05), np.float64(1.0000194883906988))

# %%
vec1, vec2 =np.array([2,3,4]), np.array([-1,-10, 0])
np.vdot(vec1, vec2)
# Out:
# np.int64(-32)

# %%
vec2.sort()
vec2[::-1]
# Out:
# array([  0,  -1, -10])

# %%
import matplotlib

# %%
import pandas

# %%
import numpy

# %%
import matplotlib.pyplot as plt

# %%
valores= np.arange(20)
plt.plot(valores, '.')

# %%
valores= np.random.normal(0,1,size=100000)
plt.hist(valores)
# Out:
# (array([5.0000e+00, 1.2600e+02, 1.8030e+03, 1.0534e+04, 2.8057e+04,
#         3.4599e+04, 1.9215e+04, 5.0410e+03, 5.9300e+02, 2.7000e+01]),
#  array([-4.80402266, -3.89054871, -2.97707476, -2.06360081, -1.15012686,
#         -0.23665291,  0.67682104,  1.59029499,  2.50376894,  3.41724289,
#          4.33071683]),
#  <BarContainer object of 10 artists>)

# %%
valores= np.random.normal(0, 1, size=100000)
plt.hist(valores, bins=100)
# Out:
# (array([1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         2.000e+00, 3.000e+00, 5.000e+00, 9.000e+00, 9.000e+00, 1.800e+01,
#         2.100e+01, 2.600e+01, 4.700e+01, 5.100e+01, 6.600e+01, 9.100e+01,
#         1.010e+02, 1.530e+02, 1.870e+02, 2.260e+02, 2.770e+02, 3.060e+02,
#         4.120e+02, 4.790e+02, 5.490e+02, 7.040e+02, 8.320e+02, 9.720e+02,
#         1.116e+03, 1.274e+03, 1.438e+03, 1.637e+03, 1.752e+03, 2.067e+03,
#         2.256e+03, 2.411e+03, 2.620e+03, 2.729e+03, 3.028e+03, 3.227e+03,
#         3.302e+03, 3.441e+03, 3.442e+03, 3.687e+03, 3.675e+03, 3.594e+03,
#         3.813e+03, 3.566e+03, 3.460e+03, 3.344e+03, 3.277e+03, 3.079e+03,
#         2.880e+03, 2.830e+03, 2.611e+03, 2.371e+03, 2.149e+03, 1.982e+03,
#         1.747e+03, 1.542e+03, 1.374e+03, 1.303e+03, 1.079e+03, 9.320e+02,
#         8.090e+02, 6.760e+02, 5.630e+02, 4.290e+02, 4.170e+02, 3.000e+02,
#         2.700e+02, 2.330e+02, 1.680e+02, 1.340e+02, 9.800e+01, 7.900e+01,
#         5.700e+01, 6.000e+01, 2.700e+01, 2.700e+01, 2.300e+01, 1.900e+01,
#         1.000e+01, 9.000e+00, 3.000e+00, 2.000e+00, 1.000e+00, 0.000e+00,
#         2.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([-4.36512151, -4.27302334, -4.18092518, -4.08882701, -3.99672885,
#         -3.90463068, -3.81253252, -3.72043435, -3.62833619, -3.53623802,
#         -3.44413986, -3.35204169, -3.25994353, -3.16784536, -3.0757472 ,
#         -2.98364903, -2.89155087, -2.79945271, -2.70735454, -2.61525638,
#         -2.52315821, -2.43106005, -2.33896188, -2.24686372, -2.15476555,
#         -2.06266739, -1.97056922, -1.87847106, -1.78637289, -1.69427473,
#         -1.60217656, -1.5100784 , -1.41798023, -1.32588207, -1.23378391,
#         -1.14168574, -1.04958758, -0.95748941, -0.86539125, -0.77329308,
#         -0.68119492, -0.58909675, -0.49699859, -0.40490042, -0.31280226,
#         -0.22070409, -0.12860593, -0.03650776,  0.0555904 ,  0.14768857,
#          0.23978673,  0.33188489,  0.42398306,  0.51608122,  0.60817939,
#          0.70027755,  0.79237572,  0.88447388,  0.97657205,  1.06867021,
#          1.16076838,  1.25286654,  1.34496471,  1.43706287,  1.52916104,
#          1.6212592 ,  1.71335737,  1.80545553,  1.8975537 ,  1.98965186,
#          2.08175002,  2.17384819,  2.26594635,  2.35804452,  2.45014268,
#          2.54224085,  2.63433901,  2.72643718,  2.81853534,  2.91063351,
#          3.00273167,  3.09482984,  3.186928  ,  3.27902617,  3.37112433,
#          3.4632225 ,  3.55532066,  3.64741882,  3.73951699,  3.83161515,
#          3.92371332,  4.01581148,  4.10790965,  4.20000781,  4.29210598,
#          4.38420414,  4.47630231,  4.56840047,  4.66049864,  4.7525968 ,
#          4.84469497]),
#  <BarContainer object of 100 artists>)

# %%
import pandas

# %%
import pandas as pd

# %%
pd.Series([4,5,6,7,8,9, 'casa']) # Tabla de una sola columna
# Out:
# 0       4
# 1       5
# 2       6
# 3       7
# 4       8
# 5       9
# 6    casa
# dtype: object

# %%
pd.Series(range(50, 56), index=['a', 'b', 'c', 'd', 'e', 'f'])
# Out:
# a    50
# b    51
# c    52
# d    53
# e    54
# f    55
# dtype: int64

# %%
serie= pd.Series([4,5,6,7,8,9], index=['a', 'b', 'c', 'd', 'e', 'f'])
serie
# Out:
# a    4
# b    5
# c    6
# d    7
# e    8
# f    9
# dtype: int64

# %%
serie['c']
# Out:
# np.int64(6)
