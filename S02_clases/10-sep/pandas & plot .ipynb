# %%
import numpy as np

# %%
np.random.rand()
# Out:
# 0.11682197789761228

# %%
np.random.rand(6,2)
# Out:
# array([[0.81733465, 0.03242055],
#        [0.13926323, 0.86728198],
#        [0.75974459, 0.75820778],
#        [0.38653109, 0.88374968],
#        [0.02832377, 0.30849594],
#        [0.08013071, 0.67655252]])

# %%
np.random.uniform()
# Out:
# 0.5015461784070427

# %%
np.random.uniform(size=[3,4])
# Out:
# array([[0.93932646, 0.05845352, 0.28212464, 0.35352297],
#        [0.06919663, 0.00805834, 0.88597645, 0.76869045],
#        [0.47169229, 0.25874664, 0.60252586, 0.78204876]])

# %%
a,b=10,15
np.random.uniform(a,b,size=[3,4])
# Out:
# array([[12.577869  , 10.55531421, 14.13137715, 14.51962376],
#        [10.91228433, 12.55736347, 10.90453542, 13.47469344],
#        [11.24734011, 14.07546062, 11.93194431, 10.75684611]])

# %%
np.random.randint(10, size=[22])
# Out:
# array([4, 3, 6, 6, 6, 4, 4, 0, 6, 6, 2, 6, 6, 5, 2, 6, 1, 3, 6, 2, 0, 3],
#       dtype=int32)

# %%
np.random.normal()
# Out:
# -0.10177231119450923

# %%
mu, sigma= -8, 4
np.random.normal(mu, sigma, size=[2,6])
# Out:
# array([[ -2.12618174,  -4.18142338, -14.96012437,  -7.86240585,
#          -8.56783633, -13.58198255],
#        [ -6.70534982,  -9.59834711,  -7.75702273, -12.47688086,
#          -8.88143554,  -3.15091412]])

# %%
valores= np.random.normal(0,1, size=1000000)
np.mean(valores), np.std(valores)
# Out:
# (np.float64(0.0012746096389787116), np.float64(1.0000954714304402))

# %%
vec1,vec2= np.array([2,3,4]), np.array([-1,-10,0])
np.vdot(vec1,vec2) ##multiplicacion de 2 vectores y da como resultado un escalar
# Out:
# np.int64(-32)

# %%
vec2.sort()
vec2
# Out:
# array([-10,  -1,   0])

# %%
vec2[: :-1]
# Out:
# array([  0,  -1, -10])

# %%
import matplotlib.pyplot as plt

# %%
valores = np.arange(20)
plt.plot(valores,".")

# %%
valores1= np.random.uniform(size=5)
plt.hist(valores1)
# Out:
# (array([2., 0., 1., 0., 0., 1., 0., 0., 0., 1.]),
#  array([0.11227043, 0.15163013, 0.19098983, 0.23034953, 0.26970922,
#         0.30906892, 0.34842862, 0.38778832, 0.42714802, 0.46650772,
#         0.50586741]),
#  <BarContainer object of 10 artists>)

# %%
## crea una variable aleatoria de numeros con media 0 y desviacion 1 de una normal de tamaño 100,000

# %%
valores3= np.random.normal(0,1, size=100000)
plt.hist(valores3)

# %%
plt.hist(valores3,nbin)
nbin=100

# %%
import pandas as pd ## hace series y data frame

# %%
pd.Series([4,5,6,7,8,9,"casa"]) ## tabla de una sola de columna
# Out:
# 0       4
# 1       5
# 2       6
# 3       7
# 4       8
# 5       9
# 6    casa
# dtype: object

# %%
pd.Series([4,5,6,7,8,9]) ## tabla de una sola de columna  ##si hay mezcla de datos todo los va considerar tipo de dato: objetos
# Out:
# 0    4
# 1    5
# 2    6
# 3    7
# 4    8
# 5    9
# dtype: int64

# %%
pd.Series(range(50,56), index=["a", "b","c","d","e","f"]) ##podemos cambiar la forma en que se nos presenta el indice
# Out:
# a    50
# b    51
# c    52
# d    53
# e    54
# f    55
# dtype: int64

# %%
serie = pd.Series([5,6,7,8,9])
serie
# Out:
# 0    5
# 1    6
# 2    7
# 3    8
# 4    9
# dtype: int64

# %%
serie[3]
# Out:
# np.int64(8)

# %%
serie = pd.Series([5,6,7,8,9], index=["a","b","c","d","e"])
serie["b"] # el sclicing es siempre sobre los indices
# Out:
# np.int64(6)
