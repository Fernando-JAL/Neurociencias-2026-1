# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import networkx as nx

# %%
#Crear grafo dirigido

G = nx.DiGraph()

G.add_nodes_from(['A','B','C','D','E'])
G.add_edges_from([('A','D'),
                  ('D','E'),
                  ('E','C'),
                  ('C','B'),
                  ('B','A')])

# %%
plt.figure(figsize=(4,4))
nx.draw_networkx(G, arrows = True, arrowstyle='-|>')

# %%
index = ['A','B','C','D','E']
matrix = pd.DataFrame(columns = index, index = index)

matrix.iloc[0,1] = 2.1
matrix.iloc[1,0] = 8.6
matrix.iloc[0,3] = 7.5
matrix.iloc[3,0] = 6.6
matrix.iloc[3,4] = 4.2
matrix.iloc[4,3] = 0.8
matrix.iloc[4,2] = 3.56
matrix.iloc[2,4] = 1.1
matrix.iloc[1,2] = 10.2
matrix.iloc[2,1] = 7.3

matrix.fillna(0, inplace = True)
matrix
# Out:
# C:\Users\V304-09\AppData\Local\Temp\ipykernel_18308\1112106150.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   matrix.fillna(0, inplace = True)
#      A    B      C    D    E
# A  0.0  2.1   0.00  7.5  0.0
# B  8.6  0.0  10.20  0.0  0.0
# C  0.0  7.3   0.00  0.0  1.1
# D  6.6  0.0   0.00  0.0  4.2
# E  0.0  0.0   3.56  0.8  0.0

# %%
G = nx.from_pandas_adjacency(matrix, create_using=nx.DiGraph())

plt.figure(figsize = (6,6))
pos = nx.spring_layout(G)
nx.draw_networkx(G, pos, with_labels= True ,arrows = True, arrowstyle='-|>', connectionstyle = 'arc3,rad=0.15')

pesos = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, pesos, label_pos = 0.3)
# Out:
# {('A', 'B'): Text(0.5983024195369522, -0.47627528310232603, '2.1'),
#  ('A', 'D'): Text(0.29600653355860396, -0.7628310393011032, '7.5'),
#  ('B', 'A'): Text(0.599784231928127, -0.10577036396835138, '8.6'),
#  ('B', 'C'): Text(0.46082993682757634, 0.462719008536709, '10.2'),
#  ('C', 'B'): Text(0.29959160987974576, 0.7500816926922975, '7.3'),
#  ('C', 'E'): Text(-0.20075203093598026, 0.7746843585362657, '1.1'),
#  ('D', 'A'): Text(-0.05747221969383087, -0.7252366449294451, '6.6'),
#  ('D', 'E'): Text(-0.5592567947486089, -0.3896335131447223, '4.2'),
#  ('E', 'C'): Text(-0.638840620887637, 0.5005826244652747, '3.56'),
#  ('E', 'D'): Text(-0.7981930654649477, -0.02832083978460176, '0.8')}

# %%
#Sacar heatmap, sacar cuartiles, y poner el umbral en el cuartil 50% y mapa de calor nuevo
