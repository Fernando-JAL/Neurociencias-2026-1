# %%
import networkx as nx

# %%
G=nx.Graph()

# %%
G.nodes(), G.edges()
# Out:
# (NodeView(((), 'b', 'B', ('A', 'B', 'C', 'D', 'E'))), EdgeView([]))

# %%
G.add_nodes_from([('A','B','C', 'D','E' )])

# %%
G.nodes(), G.edges()
# Out:
# (NodeView(((), 'b', 'B', ('A', 'B', 'C', 'D', 'E'))), EdgeView([]))

# %%
G.add_edges_from([('B','C'), ('C', 'A'), ('D','E')])

# %%
G.nodes(), G.edges()
# Out:
# (NodeView(((), 'b', 'B', ('A', 'B', 'C', 'D', 'E'), 'C', 'A', 'D', 'E')),
#  EdgeView([('B', 'C'), ('C', 'A'), ('D', 'E')]))

# %%
G.add_edge('D','A') 
nx.draw_networkx(G)

# %%
G.add_edge('C','D') 
nx.draw_networkx(G)
