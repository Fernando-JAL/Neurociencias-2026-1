# %%
import pandas as pd
import numpy as np

# %%
#activacionn de la corteza pre-frontal al escoger una eleccion de helado 
experimento={
    'sujeto':['S01','S02','S03','S02', 'S01','S01', 'S02'],
    'sabor':['choco','piñon', 'queso','chango','choco', 'queso', 'angel'],
    'precio':[45,105,30,60, 85, 45, 120],
    'tamaño':['m','g','ch','ch','g','m','g']
}

# %%
display(experimento)
# Out:
# {'sujeto': ['S01', 'S02', 'S03', 'S02', 'S01', 'S01', 'S02'],
#  'sabor': ['choco', 'piñon', 'queso', 'chango', 'choco', 'queso', 'angel'],
#  'precio': [45, 105, 30, 60, 85, 45, 120],
#  'tamaño': ['m', 'g', 'ch', 'ch', 'g', 'm', 'g']}

# %%
df=pd.DataFrame(experimento)

# %%
df['activacion']= [True,True,False,False,True, True, False]

# %%
df
# Out:
#   sujeto   sabor  precio tamaño  activacion
# 0    S01   choco      45      m        True
# 1    S02   piñon     105      g        True
# 2    S03   queso      30     ch       False
# 3    S02  chango      60     ch       False
# 4    S01   choco      85      g        True
# 5    S01   queso      45      m        True
# 6    S02   angel     120      g       False

# %%
df.sujeto
# Out:
# 0    S01
# 1    S02
# 2    S03
# 3    S02
# 4    S01
# 5    S01
# 6    S02
# Name: sujeto, dtype: object

# %%
df['precio']>100
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# Name: precio, dtype: bool

# %%
df[df['sujeto']=='S01']
# Out:
#   sujeto  sabor  precio tamaño  activacion
# 0    S01  choco      45      m        True
# 4    S01  choco      85      g        True
# 5    S01  queso      45      m        True

# %%
df[df['sujeto']=='S02']
# Out:
#   sujeto   sabor  precio tamaño  activacion
# 1    S02   piñon     105      g        True
# 3    S02  chango      60     ch       False
# 6    S02   angel     120      g       False

# %%
df[df['sujeto']=='S03']
# Out:
#   sujeto  sabor  precio tamaño  activacion
# 2    S03  queso      30     ch       False

# %%
df.groupby(by='sujeto')

# %%
df_por_sujeto=df.groupby(by='sujeto')
df_por_sujeto.describe()
# Out:
#        precio
#         count       mean        std   min   25%    50%    75%    max
# sujeto
# S01       3.0  58.333333  23.094011  45.0  45.0   45.0   65.0   85.0
# S02       3.0  95.000000  31.224990  60.0  82.5  105.0  112.5  120.0
# S03       1.0  30.000000        NaN  30.0  30.0   30.0   30.0   30.0

# %%
df_por_sujeto=df.groupby(by='sujeto')
df_por_sujeto.describe(include='all')
# Out:
#        sabor                                                   ... activacion  \
#        count unique    top freq mean  std  min  25%  50%  75%  ...     unique
# sujeto                                                         ...
# S01        3      2  choco    2  NaN  NaN  NaN  NaN  NaN  NaN  ...          1
# S02        3      3  piñon    1  NaN  NaN  NaN  NaN  NaN  NaN  ...          2
# S03        1      1  queso    1  NaN  NaN  NaN  NaN  NaN  NaN  ...          1
#
#
#           top freq mean  std  min  25%  50%  75%  max
# sujeto
# S01      True    3  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# S02     False    2  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# S03     False    1  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [3 rows x 44 columns]

# %%
tipos_sujetos = ['S' + str(i).zfill(2) for i in range(4)]
generos= ['M','F']
condicion=['control', 'experimental']
region=['hipocampo','cortex prefrontal', 'amigdala']
neurotransmisores=['dopamina','serotonina']

#Crea un dataframe de 200 filas)
#con las columnas tipo_sujetos, genero,condicion, region, neurotransmisor,
#estas clumnas debe de tener distribucion normal 
#agragar columna llamda "presion" q tenga una distribucion normal con med 0.92 y sigma 0.8
#Este data pretende simular los resultados de un estudio en el que se mide variable congnitivo
#y fisiologicamente difernete s regiones cerebrales, sujetos y condiciones experiemntales

# %%
import numpy as np

tipos_sujetos = ['S' + str(i).zfill(2) for i in range(4)]

longitud = 200
enteros = np.random.randint(0, 4, size=longitud)
sujetos = ['S' + str(i).zfill(2) for i in enteros]
display(sujetos)
# Out:
# ['S00',
#  'S00',
#  'S00',
#  'S00',
#  'S02',
#  'S02',
#  'S02',
#  'S01',
#  'S03',
#  'S00',
#  'S01',
#  'S02',
#  'S02',
#  'S02',
#  'S03',
#  'S01',
#  'S01',
#  'S00',
#  'S01',
#  'S02',
#  'S02',
#  'S01',
#  'S02',
#  'S00',
#  'S02',
#  'S00',
#  'S03',
#  'S02',
#  'S03',
#  'S02',
#  'S00',
#  'S00',
#  'S01',
#  'S00',
#  'S00',
#  'S03',
#  'S01',
#  'S03',
#  'S03',
#  'S02',
#  'S03',
#  'S02',
#  'S00',
#  'S00',
#  'S02',
#  'S01',
#  'S02',
#  'S03',
#  'S00',
#  'S02',
#  'S01',
#  'S03',
#  'S00',
#  'S00',
#  'S00',
#  'S00',
#  'S01',
#  'S02',
#  'S00',
#  'S03',
#  'S01',
#  'S03',
#  'S02',
#  'S01',
#  'S02',
#  'S01',
#  'S03',
#  'S03',
#  'S01',
#  'S01',
#  'S03',
#  'S01',
#  'S00',
#  'S01',
#  'S03',
#  'S01',
#  'S01',
#  'S02',
#  'S00',
#  'S00',
#  'S01',
#  'S01',
#  'S00',
#  'S00',
#  'S02',
#  'S00',
#  'S02',
#  'S02',
#  'S02',
#  'S00',
#  'S00',
#  'S02',
#  'S02',
#  'S01',
#  'S01',
#  'S03',
#  'S00',
#  'S00',
#  'S01',
#  'S03',
# ...

# %%
tipos_sujetos = ['S' + str(i).zfill(2) for i in range(4)]
longitud = 200
ops_sujetos=np.random.randint(len(tipos_sujetos) ,size=longitud)
sujetos2= ['S' + str(i).zfill(2) for i in ops_sujetos]

sujetos2
# Out:
# ['S01',
#  'S00',
#  'S02',
#  'S02',
#  'S03',
#  'S01',
#  'S02',
#  'S01',
#  'S01',
#  'S00',
#  'S00',
#  'S01',
#  'S03',
#  'S03',
#  'S02',
#  'S01',
#  'S03',
#  'S01',
#  'S01',
#  'S03',
#  'S03',
#  'S01',
#  'S01',
#  'S03',
#  'S02',
#  'S01',
#  'S00',
#  'S01',
#  'S03',
#  'S00',
#  'S02',
#  'S01',
#  'S00',
#  'S01',
#  'S02',
#  'S00',
#  'S00',
#  'S02',
#  'S01',
#  'S01',
#  'S03',
#  'S03',
#  'S00',
#  'S01',
#  'S00',
#  'S02',
#  'S01',
#  'S01',
#  'S01',
#  'S03',
#  'S02',
#  'S01',
#  'S02',
#  'S03',
#  'S00',
#  'S03',
#  'S01',
#  'S03',
#  'S03',
#  'S00',
#  'S02',
#  'S00',
#  'S03',
#  'S02',
#  'S00',
#  'S03',
#  'S00',
#  'S00',
#  'S03',
#  'S00',
#  'S02',
#  'S03',
#  'S03',
#  'S01',
#  'S00',
#  'S00',
#  'S01',
#  'S00',
#  'S02',
#  'S00',
#  'S02',
#  'S02',
#  'S03',
#  'S00',
#  'S01',
#  'S00',
#  'S00',
#  'S02',
#  'S02',
#  'S00',
#  'S03',
#  'S03',
#  'S00',
#  'S00',
#  'S03',
#  'S02',
#  'S01',
#  'S00',
#  'S02',
#  'S03',
# ...

# %%
generos = ['M','F']
longitud = 200
ops_generos = np.random.randint(len(generos), size=longitud)
gen = []
for x in ops_generos:  
    if x == 0:
        gen.append('M')
    else:
        gen.append('F')

generos
# Out:
# ['M', 'F']

# %%
import numpy as np
import pandas as pd

longitud = 200
tipos_sujetos = ['S' + str(i).zfill(2) for i in range(4)]

ops_sujetos = np.random.randint(len(tipos_sujetos), size=longitud)
col_sujetos = [tipos_sujetos[i] for i in ops_sujetos]

col_sujetos

generos = ['M', 'F']
ops_generos = np.random.randint(len(generos), size=longitud)
col_generos = [generos[i] for i in ops_generos]

generos

condicion = ['control', 'experimental']
ops_cond = np.random.randint(len(condicion), size=longitud)
col_cond = [condicion[i] for i in ops_cond]

condicion

region = ['hipocampo', 'cortex prefrontal', 'amigdala']
ops_region = np.random.randint(len(region), size=longitud)
col_region = [region[i] for i in ops_region]

region

neurotransmisores = ['dopamina', 'serotonina']
ops_neuro = np.random.randint(len(neurotransmisores), size=longitud)
col_neuro = [neurotransmisores[i] for i in ops_neuro]

neurotransmisores 

col_presion = np.random.normal(loc=0.92, scale=0.8, size=longitud)

col_presion


df = pd.DataFrame({
    "tipo_sujeto": col_sujetos,
    "genero": col_generos,
    "condicion": col_cond,
    "region": col_region,
    "neurotransmisor": col_neuro,
    "presion": col_presion
})

print(df.head())

display(df.head())

display(df["genero"].value_counts())
display(df["condicion"].value_counts())
display(df["region"].value_counts())
display(df["neurotransmisor"].value_counts())
# Out:
#   tipo_sujeto genero     condicion             region neurotransmisor  \
# 0         S02      F       control          hipocampo      serotonina
# 1         S02      F       control  cortex prefrontal        dopamina
# 2         S03      F  experimental          hipocampo        dopamina
# 3         S00      F  experimental  cortex prefrontal        dopamina
# 4         S02      F       control  cortex prefrontal      serotonina
#
#     presion
# 0  2.031684
# 1  0.325156
# 2  1.014886
# 3  0.959088
# 4 -0.483184
#   tipo_sujeto genero     condicion             region neurotransmisor  \
# 0         S02      F       control          hipocampo      serotonina
# 1         S02      F       control  cortex prefrontal        dopamina
# 2         S03      F  experimental          hipocampo        dopamina
# 3         S00      F  experimental  cortex prefrontal        dopamina
# 4         S02      F       control  cortex prefrontal      serotonina
#
#     presion
# 0  2.031684
# 1  0.325156
# ...

# %%
#generar el histograma de cuantos datos por sujeto se tiene
#mostrar histograma la proporcion de neurotransmisor 

import matplotlib.pyplot as plt

plt.hist(df['tipo_sujeto'], color='blue', alpha=0.5)
plt.show()

# %%
grupos=df.groupby(by=['sujeto'.'condicion2'])
# Out:
#   Cell In[5], line 1
#     grupos=df.groupby(by=['sujeto'.'condicion2'])
#                                    ^
# SyntaxError: invalid syntax

# %%
llaves= grupos.groups.keys()
llaves
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 llaves= grupos.groups.keys()
#       2 llaves
#
# NameError: name 'grupos' is not defined

# %%
grupos.get_group(list(llaves)[0]).head(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 grupos.get_group(list(llaves)[0]).head(3)
#
# NameError: name 'grupos' is not defined

# %%
control= df[df['sujetos']=='S00']
sujeto0=control[control['condicion2']=='control']
sujeto0.head(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 control= df[df['sujetos']=='S00']
#       2 sujeto0=control[control['condicion2']=='control']
#       3 sujeto0.head(3)
#
# NameError: name 'df' is not defined

# %%
sujeto0=df[df[(df.sujetos=='S00')&(df.condicion2=='control')]
sujeto0.head(3)
# Out:
#   Cell In[7], line 1
#     sujeto0=df[df[(df.sujetos=='S00')&(df.condicion2=='control')]
#               ^
# SyntaxError: '[' was never closed

# %%
sujeto0=df[df[(df.sujetos=='S00')&(df.condicion2=='control')]
sujeto0=df[df[(df.sujetos=='S00')&(df.condicion2=='control')]
sujeto0.head(3)
# Out:
#   Cell In[8], line 1
#     sujeto0=df[df[(df.sujetos=='S00')&(df.condicion2=='control')]
#                ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
