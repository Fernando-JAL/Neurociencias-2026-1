# %% [markdown]
# # Grafos

# %% [markdown]
# ## Correlacion de pearson
# correlación en el tiempo entre areas/nodos
#
# ## Coherencia esprectral
# Considerando todo el tiempo, se ven las frecuencias (sacadas por los senos de la frecuencia) y se clasifican
#
# ##

# %%
pip install networkx
# Out:
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    --------------- ------------------------ 0.8/2.0 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 6.2 MB/s  0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import networkx as nx

# %%
G= nx.Graph()

# %%
#determinar nodos
G.nodes()

# %%
#determinar aristas
G.edges()

# %%
G.add_nodes_from(['A','B','C','D','E'])

# %%
G.nodes
# Out:
# NodeView(('A', 'B', 'C', 'D', 'E'))

# %%
G.add_edges_from([('B','C'),('C','A'),('D','E'),('C','D')])

# %%
G.edges
# Out:
# EdgeView([('A', 'C'), ('A', 'D'), ('B', 'C'), ('C', 'D'), ('D', 'E')])

# %%
nx.draw_networkx(G)

# %%
import matplotlib.pyplot as plt

# %%
# Crear una lista de colores para las aristas
edge_colors = ['red', 'blue', 'green', 'purple']

# %%
# Dibujar el grafo con los colores de aristas especificados
nx.draw(G, with_labels=True, edge_color='purple', width=2) # 'width' hace las aristas más gruesas
plt.show()
