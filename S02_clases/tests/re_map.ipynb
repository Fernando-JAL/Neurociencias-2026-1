# %%
# -- coding: utf-8 --
"""
Coloriza una imagen PNG en escala de grises con un colormap 'hot' calibrado 20–50 °C.
La imagen de entrada se reescala a temperaturas entre 20 °C y max_temperature,
y luego se aplica el mapa 'hot' definido en 20–50 °C.

Requisitos:
  pip install pillow matplotlib numpy
"""

from PIL import Image
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import os

# %%
def reescale_map_color(input_path, output_path, min_temperature, max_temperature, cmap_vmin=20.0, cmap_vmax=50.0, legend_path = "leyenda_20_50.png"):
    # 1) Abrir imagen y convertir a escala de grises [0, 1]
    img = Image.open(input_path).convert("L")  # "L" = 8-bit grayscale
    gray = np.asarray(img, dtype=np.float32) / 255.0
    
    # 2) Reescalar a temperaturas físicas en °C usando 20..max_temperature
    #    T = 20 + gray*(maxT - 20)
    temperatures = min_temperature + gray * (max_temperature - min_temperature)
    
    # 3) Clipping a 20..50 para pintar con el colormap calibrado 20–50 °C
    temperatures_for_colormap = np.clip(temperatures, cmap_vmin, cmap_vmax)
    
    # 4) Crear el mapa 'hot' con normalización fija 20–50 °C
    norm = mpl.colors.Normalize(vmin=cmap_vmin, vmax=cmap_vmax)
    cmap = mpl.cm.get_cmap("plasma")  # también podrías usar mpl.cm.hot
    
    # 5) Aplicar colormap -> matriz RGBA en [0,1]
    rgba = cmap(norm(temperatures_for_colormap))  # shape (H, W, 4)
    
    # 6) Guardar imagen color (RGB en 8 bits)
    rgb_uint8 = (rgba[..., :3] * 255).astype(np.uint8)

    output_folder = "\\".join(output_path.split(sep="\\")[:-1])
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    Image.fromarray(rgb_uint8, mode="RGB").save(output_path)
    print(f"Imagen colorizada guardada en: {output_path}")
    
    # 7) (Opcional) Guardar una leyenda/escala de colores 20–50 °C
    fig, ax = plt.subplots(figsize=(5, 1.0), dpi=200)
    fig.subplots_adjust(bottom=0.5)
    
    cb1 = mpl.colorbar.ColorbarBase(
        ax,
        cmap=cmap,
        norm=norm,
        orientation='horizontal'
    )
    cb1.set_label("Temperatura [°C]")
    fig.savefig(legend_path, bbox_inches="tight")
    plt.close(fig)
    print(f"Leyenda guardada en: {legend_path}")
    
    # 8) Información útil en consola
    print(f"Rango real de la imagen reescalada antes de pintar: "
          f"{temperatures.min():.2f}–{temperatures.max():.2f} °C")
    print(f"El colormap se aplicó con vmin={cmap_vmin} °C y vmax={cmap_vmax} °C.")

# %%
# ----------------- Parámetros del usuario -----------------
# input_folder = r"C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas"
# img_name = "2 bhrs.JPG"
# input_path_ = os.path.join(input_folder, img_name)

output_folder = r"C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas"

legend_path = "leyenda_20_50.png"   # Imagen con la barra de colores (opcional)
max_temperature = 47.5              # <-- Ajusta aquí el máximo de TU captura (°C)
min_temperature = 20.0              # Fijo en 20 °C
cmap_vmin = 20.0                    # Límite inferior del mapa de colores
cmap_vmax = 50.0                    # Límite superior del mapa de colores
# -----------------------------------------------------------


# Ruta principal donde buscar imágenes
ruta_base = r"C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas"  # 🔹 Cambia esto por tu ruta

# Extensiones válidas de imágenes
extensiones = ('.png', '.jpg', '.jpeg', '.bmp', '.tiff', '.tif', '.gif')

# Lista para guardar rutas encontradas
imagenes_encontradas = []

# Recorre todas las carpetas y subcarpetas
for carpeta_raiz, carpetas, archivos in os.walk(ruta_base):
    for archivo in archivos:
        if archivo.lower().endswith(extensiones):
            ruta_completa = os.path.join(carpeta_raiz, archivo)
            imagenes_encontradas.append(ruta_completa)

            subfolder = "\\".join(ruta_completa.split(sep="\\")[9:-1])
            output_path = os.path.join(output_folder, subfolder, "procesados_"+img_name) # PNG colorizado
            
            reescale_map_color(ruta_completa, output_path, min_temperature, max_temperature)

# Mostrar resultados
print("📁 Imágenes encontradas:")
for img in imagenes_encontradas:
    print(img)

print(f"\nTotal de imágenes encontradas: {len(imagenes_encontradas)}")
# Out:
# C:\Users\OMEN CI7\AppData\Local\Temp\ipykernel_416\1169564654.py:15: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = mpl.cm.get_cmap("plasma")  # también podrías usar mpl.cm.hot
# C:\Users\OMEN CI7\AppData\Local\Temp\ipykernel_416\1169564654.py:26: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   Image.fromarray(rgb_uint8, mode="RGB").save(output_path)
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.24–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 24.21–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Disco duro (Foto térmica )\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Disco duro (Foto térmica )\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Disco duro (Foto térmica )\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Disco duro (Foto térmica )\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Disco duro (Foto térmica )\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Disco duro (Foto térmica )\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Disco duro (Foto térmica )\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Disco duro (Foto térmica )\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Disco duro (Foto térmica )\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Disco duro (Foto térmica )\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Disco duro (Foto térmica )\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Disco duro (Foto térmica )\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.24–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 22.48–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 22.70–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.67–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.77–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.67–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.13–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 22.80–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.24–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.24–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.99–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.99–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.24–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.67–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.45–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 22.59–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.56–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.83–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.77–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.67–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.34–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.67–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1  y 2 (3 horas ) Fotos térmicas 7_30-10_30\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1  y 2 (3 horas ) Fotos térmicas 7_30-10_30\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1  y 2 (3 horas ) Fotos térmicas 7_30-10_30\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1  y 2 (3 horas ) Fotos térmicas 7_30-10_30\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1  y 2 (3 horas ) Fotos térmicas 7_30-10_30\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1  y 2 (3 horas ) Fotos térmicas 7_30-10_30\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1  y 2 (3 horas ) Fotos térmicas 7_30-10_30\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1  y 2 (3 horas ) Fotos térmicas 7_30-10_30\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1  y 2 (3 horas ) Fotos térmicas 7_30-10_30\Lab 1\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1  y 2 (3 horas ) Fotos térmicas 7_30-10_30\Lab 2\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1  y 2 (3 horas ) Fotos térmicas 7_30-10_30\Lab 2\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1  y 2 (3 horas ) Fotos térmicas 7_30-10_30\Lab 2\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1  y 2 (3 horas ) Fotos térmicas 7_30-10_30\Lab 2\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1  y 2 (3 horas ) Fotos térmicas 7_30-10_30\Lab 2\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1  y 2 (3 horas ) Fotos térmicas 7_30-10_30\Lab 2\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1  y 2 (3 horas ) Fotos térmicas 7_30-10_30\Lab 2\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Domingo (2 hrs)\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Domingo (2 hrs)\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.94–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Domingo (2 hrs)\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Fotos con ruido\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Fotos con ruido\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Fotos con ruido\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Fotos con ruido\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Fotos con ruido\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Fotos con ruido\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Fotos con ruido\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.88–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Fotos con ruido\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.94–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Fotos con ruido\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Fotos con ruido\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.83–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Fotos con ruido\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Fotos con ruido\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.83–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Fotos con ruido\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.77–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Fotos con ruido\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 22.37–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Fotos con ruido\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.99–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Fotos con ruido\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.88–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Fotos con ruido\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Fotos con ruido\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Fotos con ruido\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Fotos con ruido\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Fotos con ruido 2-3-6 hrs\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Fotos con ruido 2-3-6 hrs\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Fotos con ruido 2-3-6 hrs\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Fotos con ruido 2-3-6 hrs\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Fotos con ruido 2-3-6 hrs\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Fotos con ruido 2-3-6 hrs\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Fotos con ruido 2-3-6 hrs\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Fotos con ruido 2-3-6 hrs\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.62–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 0 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.99–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 0 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.24–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 0 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.88–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 0 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.99–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 0 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.24–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 0 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.67–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 0 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.67–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 0 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.88–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 0 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.77–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 0 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.56–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 0 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.77–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 0 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.77–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 0 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.67–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 0 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.67–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 0 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.67–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 0 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.67–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 0 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.45–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 0 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.99–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 0 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.34–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 5 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.88–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 5 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.24–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 5 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.67–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 5 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.77–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 5 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.67–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 5 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.88–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 5 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 22.91–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 5 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.77–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 5 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.67–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 5 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.88–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 5 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 22.26–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 5 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.56–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 5 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.56–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 5 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 21.83–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 5 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.88–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 5 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.56–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 5 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.56–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 5 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 23.67–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# Imagen colorizada guardada en: C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\nuevos_termogramas\Lab 1 Gabinetes 5 min\procesados_2 bhrs.JPG
# Leyenda guardada en: leyenda_20_50.png
# Rango real de la imagen reescalada antes de pintar: 22.37–47.50 °C
# El colormap se aplicó con vmin=20.0 °C y vmax=50.0 °C.
# ...
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 (3 horas)\9.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 (6 horas)\IMG_0397.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 (6 horas)\IMG_0398.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 (6 horas)\IMG_0399.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 (6 horas)\IMG_0400.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos con ruido\Máquina 1 ruido.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos con ruido\Máquina 12 ruido(1).jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos con ruido\Máquina 12 ruido.jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos con ruido\Máquina 13 ruido.jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos con ruido\Máquina 14 ruido(1).jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos con ruido\Máquina 14 ruido.jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos con ruido\Máquina 15 ruido(1).jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos con ruido\Máquina 15 ruido(2).jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos con ruido\Máquina 15 ruido.jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos con ruido\Máquina 16 ruido(1).jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos con ruido\Máquina 16 ruido.jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos con ruido\Máquina 17 ruido.jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos con ruido\Máquina 3 ruido.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos con ruido\Máquina 5 ruido.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos con ruido\Máquina 6 ruido.jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos con ruido\Máquina 9 ruido.jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Maquina 1.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Maquina 8.jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 1.jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 10(1).jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 10(2).jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 10.jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 11(1).jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 11(2).jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 11.jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 12.jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 13(1).jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 13.jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 14.jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 16.jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 17.jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 18(1).jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 18.jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 19(1).jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 19.jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 2(1).JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 2(2).JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 2.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 3(1).JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 3.jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 4(1).jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 4(2).JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 4.jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 5(1).jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 5.jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 6(1).jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 6.jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 7(1).jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 7(2).jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 7.jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 8(1).jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 8.jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 9(1).jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 Fotos térmicas\Máquina 9.jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 0 min\1.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 0 min\10.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 0 min\12.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 0 min\13.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 0 min\14.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 0 min\15.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 0 min\16.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 0 min\2.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 0 min\3.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 0 min\4.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 0 min\5.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 0 min\6.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 0 min\7.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 0 min\8.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 0 min\9.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 0 min\IMG_0535.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 0 min\ruido.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 5 min\1.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 5 min\10.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 5 min\12.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 5 min\13.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 5 min\14.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 5 min\15.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 5 min\16.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 5 min\2.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 5 min\3.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 5 min\4.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 5 min\5.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 5 min\6.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 5 min\7.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 5 min\8.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 5 min\9.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 60 min\IMG_0555.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 60 min\IMG_0560.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 60 min\IMG_0567.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 60 min\IMG_0570.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 60 min\IMG_0573.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 60 min\IMG_0574.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 60 min\IMG_0575.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 60 min\IMG_0576.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 60 min\IMG_0577.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 60 min\IMG_0578.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 60 min\IMG_0579.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 60 min\IMG_0580.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 60 min\IMG_0581.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 60 min\IMG_0582.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 60 min\IMG_0583.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 60 min\IMG_0584.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 60 min\IMG_0585.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Lab 7 gabinetes 60 min\IMG_0586.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Ruido\IMG_0102.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Ruido\IMG_0107.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Ruido\IMG_0110.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Ruido\IMG_0113.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Ruido\IMG_0114.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Ruido\IMG_0116.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Ruido\IMG_0117.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Ruido\IMG_0123.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Ruido\IMG_0234.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Ruido\IMG_0515.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Ruido\IMG_0516.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Ruido\IMG_0522.JPG
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Ruido\Máquina 1.jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Ruido\Máquina 3 ruido.jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Ruido\Máquina 5 (no pertenece).jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Ruido\Máquina 5 (no se queda).jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Ruido\Máquina 6(se repite con la 5).jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Ruido\Máquina 8 (ruido).jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Ruido\Máquina(1).jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Ruido\Máquina(2).jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Ruido\Máquina.jpg
# C:\Users\OMEN CI7\Documents\repository\Neurociencias-2026-1\S02_clases\tests\termogramas\Ruido\RUIDO.JPG
#
# Total de imágenes encontradas: 557
