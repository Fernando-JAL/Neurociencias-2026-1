# %%
import numpy as np

# %%
np.random.rand(6,2)
# Out:
# array([[0.128028  , 0.59245221],
#        [0.52510122, 0.77299537],
#        [0.95302709, 0.08925951],
#        [0.9951214 , 0.24547918],
#        [0.70558175, 0.79187288],
#        [0.42446784, 0.05496092]])

# %%
a,b=10, 150 #asignar valores
np.random.uniform(a,b,size=[3,4]) #(lim inf, lim sup, size)
# Out:
# array([[ 78.11120648, 115.64088749,  57.02209079, 147.08938845],
#        [ 33.43319319,  80.66531565,  86.19907175,  92.28583139],
#        [ 46.90199606, 116.04615913,  42.43734095,  92.18219097]])

# %%
np.random.randint(10, size=[22])
# Out:
# array([2, 0, 6, 3, 8, 3, 2, 3, 8, 3, 1, 0, 5, 8, 2, 1, 1, 1, 2, 6, 3, 7],
#       dtype=int32)

# %%
mu, sigma= -8,4
np.random.normal (mu, sigma, size=[2,6])
# Out:
# array([[ -9.95558932,  -6.6679818 ,  -8.62571959,  -8.17147304,
#          -5.9512454 ,  -3.73393532],
#        [ -7.90950182,  -8.88037389, -11.5138602 , -10.43510512,
#          -8.75872157,  -6.73714452]])

# %%
valores = np.random.normal(0,1,size=100000)
np.mean(valores), np.std(valores)
# Out:
# (np.float64(0.0004357271275043146), np.float64(0.997162014980503))

# %% [markdown]
# hay muchas operaciones de

# %%
vec1, vec2= np.array([2,3,4]), np.array ([-1,-10,0])
np.vdot(vec1,vec2)
# Out:
# np.int64(-32)

# %%
vec2.sort()
vec2[::-1] #para que nos los de mayor a menor
# Out:
# array([  0,  -1, -10])

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## numpy se enfoca en arreglos
# ## libreria para graficar

# %%
valores= np.arange(20) #arreglo de 20 elementos 
plt.plot(valores)

# %%
valor= np.random.uniform(size=100)
plt.hist(valor)
# Out:
# (array([10., 10.,  8.,  8., 12.,  8., 13.,  4., 17., 10.]),
#  array([0.01643193, 0.11337277, 0.21031362, 0.30725447, 0.40419531,
#         0.50113616, 0.598077  , 0.69501785, 0.7919587 , 0.88889954,
#         0.98584039]),
#  <BarContainer object of 10 artists>)

# %%
# crear variable aleatoria de numeros con media 0, sd 1 y tamaño de 100,000 y su histograma

mu,sigma= 0,1
x=np.random.normal(mu, sigma, size=100000)
plt.hist(x,bins=100);
