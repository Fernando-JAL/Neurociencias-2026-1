# %% [markdown]
# # NetworkX
#
# - Correlación de pearson, coherencia espectral y face locking value --> para construir matriz de conectividad

# %%
import networkx as nx

# %%
G = nx.Graph()

# %% [markdown]
# nodes --> nodos
#
# edges --> aristas

# %%
G.nodes(), G.edges()
# Out:
# (NodeView(()), EdgeView([]))

# %%
# definir nuestros nodos
G.add_nodes_from([ "A", "B", "C", "D", "E" ])

# %%
G.nodes(), G.edges()
# Out:
# (NodeView(('A', 'B', 'C', 'D', 'E')), EdgeView([]))

# %%
G.add_edges_from([ ("B", "C"), ("C", "A"), ("D", "E") ])

# %%
G.nodes(), G.edges()
# Out:
# (NodeView(('A', 'B', 'C', 'D', 'E')),
#  EdgeView([('A', 'C'), ('A', 'D'), ('B', 'C'), ('D', 'E')]))

# %%
G.add_edge("C", "D")
nx.draw_networkx(G)

# %%
# hay diferentes formas de mostrar un grafo
nx.draw_spring(G)
