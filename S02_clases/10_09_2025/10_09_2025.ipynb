# %%
import numpy as np

# %%
np.random.rand(6, 2)
# Out:
# array([[0.43070199, 0.18663187],
#        [0.87140769, 0.96023353],
#        [0.64003715, 0.0334926 ],
#        [0.36007434, 0.75068868],
#        [0.71266361, 0.3907943 ],
#        [0.2648578 , 0.85421248]])

# %%
a, b =10,15
np.random.uniform(a, b, size=[3, 4])
# Out:
# array([[10.12822957, 11.10177152, 12.84284171, 11.9153504 ],
#        [14.68081631, 13.89635348, 13.11032634, 13.80558057],
#        [13.26100429, 12.58601003, 14.2050265 , 11.76615997]])

# %%
np.random.randint(10, size=[22])
# Out:
# array([7, 5, 0, 6, 7, 0, 4, 8, 7, 6, 2, 6, 8, 5, 7, 1, 1, 7, 2, 1, 0, 1],
#       dtype=int32)

# %%
np.random.normal()
# Out:
# -1.2448423660109207

# %%
mu, sigma = -8,4
np.random.normal(mu, sigma, size=[2, 6])
# Out:
# array([[ -5.04896066,  -8.32745504,  -8.02561076, -14.10192338,
#          -3.19363527,  -9.49799638],
#        [ -2.86565445,  -3.78526824, -11.45548028, -12.79275583,
#          -4.17200628,  -9.07514481]])

# %%
valores = np.random.normal(0,1, size= 10000000)
np.mean(valores), np.std(valores)
# Out:
# (np.float64(0.00021379220928242502), np.float64(1.0000556190828491))

# %%
vec1, vec2 = np.array([2, 3, 4]), np.array([-1, -10, 0])
np.vdot(vec1, vec2)
# Out:
# np.int64(-32)

# %%
vec2.sort()
vec2[::-1]
# Out:
# array([  0,  -1, -10])

# %%
import matplotlib.pyplot as plt

# %%
valores = np.arange(20)
plt.plot(valores)

# %%
valores = np.random.uniform(size=100000)
plt.hist(valores)
# Out:
# (array([ 9979., 10081., 10072.,  9917., 10147.,  9915., 10028., 10018.,
#          9958.,  9885.]),
#  array([4.86237053e-07, 1.00000033e-01, 1.99999580e-01, 2.99999127e-01,
#         3.99998674e-01, 4.99998221e-01, 5.99997768e-01, 6.99997314e-01,
#         7.99996861e-01, 8.99996408e-01, 9.99995955e-01]),
#  <BarContainer object of 10 artists>)

# %%
valores
# Out:
# array([0.99351498, 0.38187603, 0.07946089, 0.57519301, 0.07346671])

# %%
#ejercicio crear un arreglo de numeros aleatorios con distribucion normal con mu = 0 y desviación estandar = 1 de tamaño 100,000 y plotear su histograma
valores = np.random.normal (0,1, size=100000)
plt.hist(valores, bins=100)
# Out:
# (array([1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 1.000e+00,
#         0.000e+00, 1.000e+00, 2.000e+00, 0.000e+00, 5.000e+00, 7.000e+00,
#         5.000e+00, 6.000e+00, 1.100e+01, 1.500e+01, 3.100e+01, 3.500e+01,
#         4.500e+01, 5.500e+01, 7.700e+01, 1.300e+02, 1.290e+02, 1.720e+02,
#         2.270e+02, 2.700e+02, 3.480e+02, 4.210e+02, 5.170e+02, 6.230e+02,
#         7.210e+02, 8.600e+02, 1.017e+03, 1.055e+03, 1.321e+03, 1.469e+03,
#         1.685e+03, 1.766e+03, 2.094e+03, 2.377e+03, 2.459e+03, 2.660e+03,
#         2.944e+03, 3.075e+03, 3.332e+03, 3.479e+03, 3.652e+03, 3.554e+03,
