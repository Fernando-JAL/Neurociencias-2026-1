# %%
import pandas as pd
import numpy as np

# %%
experimento = {
    'sujeto': ['S01','S02','S03','S02','S01','S01','S02'],
    'sabor': ['choco','piñon','queso','chango','choco','queso','angel'],
    'precio':[45,105,30,60,85,45,120],
    'tamaño':['m','g','ch','ch','g','m','g']
}

# %%
experimento
# Out:
# {'sujeto': ['S01', 'S02', 'S03', 'S02', 'S01', 'S01', 'S02'],
#  'sabor': ['choco', 'piñon', 'queso', 'chango', 'choco', 'queso', 'angel'],
#  'precio': [45, 105, 30, 60, 85, 45, 120],
#  'tamaño': ['m', 'g', 'ch', 'ch', 'g', 'm', 'g']}

# %%
df= pd.DataFrame(experimento)

# %%
df
# Out:
#   sujeto   sabor  precio tamaño
# 0    S01   choco      45      m
# 1    S02   piñon     105      g
# 2    S03   queso      30     ch
# 3    S02  chango      60     ch
# 4    S01   choco      85      g
# 5    S01   queso      45      m
# 6    S02   angel     120      g

# %%
df['activación'] = [True, True, False,False,True,True,False]
df

### para añadir una nueva columna
# Out:
#   sujeto   sabor  precio tamaño  activación
# 0    S01   choco      45      m        True
# 1    S02   piñon     105      g        True
# 2    S03   queso      30     ch       False
# 3    S02  chango      60     ch       False
# 4    S01   choco      85      g        True
# 5    S01   queso      45      m        True
# 6    S02   angel     120      g       False

# %%
df['sujeto']
## para filtrar una columna
# Out:
# 0    S01
# 1    S02
# 2    S03
# 3    S02
# 4    S01
# 5    S01
# 6    S02
# Name: sujeto, dtype: object

# %%
## filtrado especifico
df [df['precio'] > 100]
# Out:
#   sujeto  sabor  precio tamaño  activación
# 1    S02  piñon     105      g        True
# 6    S02  angel     120      g       False

# %%
df [df['sujeto'] == 'S01']
# Out:
#   sujeto  sabor  precio tamaño  activación
# 0    S01  choco      45      m        True
# 4    S01  choco      85      g        True
# 5    S01  queso      45      m        True

# %%
df [df['sujeto'] == 'S02']
# Out:
#   sujeto   sabor  precio tamaño  activación
# 1    S02   piñon     105      g        True
# 3    S02  chango      60     ch       False
# 6    S02   angel     120      g       False

# %%
df [df['sujeto'] == 'S03']
# Out:
#   sujeto  sabor  precio tamaño  activación
# 2    S03  queso      30     ch       False

# %%
df.groupby(by = 'sujeto')

# %%
df_por_sujeto = df.groupby(by='sujeto')
df_por_sujeto.describe()
# Out:
#        precio
#         count       mean        std   min   25%    50%    75%    max
# sujeto
# S01       3.0  58.333333  23.094011  45.0  45.0   45.0   65.0   85.0
# S02       3.0  95.000000  31.224990  60.0  82.5  105.0  112.5  120.0
# S03       1.0  30.000000        NaN  30.0  30.0   30.0   30.0   30.0

# %%
df_por_sujeto = df.groupby(by='sujeto')
df_por_sujeto.describe(include='all')

## hay muchos NaN porque no puedes establecer la media para datos no numericos
# Out:
#        sabor                                                   ... activación  \
#        count unique    top freq mean  std  min  25%  50%  75%  ...     unique
# sujeto                                                         ...
# S01        3      2  choco    2  NaN  NaN  NaN  NaN  NaN  NaN  ...          1
# S02        3      3  piñon    1  NaN  NaN  NaN  NaN  NaN  NaN  ...          2
# S03        1      1  queso    1  NaN  NaN  NaN  NaN  NaN  NaN  ...          1
#
#
#           top freq mean  std  min  25%  50%  75%  max
# sujeto
# S01      True    3  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# S02     False    2  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# S03     False    1  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [3 rows x 44 columns]

# %%
df.describe()
# Out:
#           precio
# count    7.00000
# mean    70.00000
# std     33.91165
# min     30.00000
# 25%     45.00000
# 50%     60.00000
# 75%     95.00000
# max    120.00000

# %%
df.describe(include='all')
# Out:
#        sujeto  sabor     precio tamaño activación
# count       7      7    7.00000      7          7
# unique      3      5        NaN      3          2
# top       S01  choco        NaN      g       True
# freq        3      2        NaN      3          4
# mean      NaN    NaN   70.00000    NaN        NaN
# std       NaN    NaN   33.91165    NaN        NaN
# min       NaN    NaN   30.00000    NaN        NaN
# 25%       NaN    NaN   45.00000    NaN        NaN
# 50%       NaN    NaN   60.00000    NaN        NaN
# 75%       NaN    NaN   95.00000    NaN        NaN
# max       NaN    NaN  120.00000    NaN        NaN

# %%
tipos_sujetos = ['S'+str(i).zfill(2) for i in range(4)]
generos = ['M', 'F']
condicion = ['control', 'experimental']
region = ['hipocampo','cortex prefrontal', 'amigdala']
neurotransmisor = ['dopamina','serotonina']

## crea un df de 200 filas
## con las columnas de arriba
## estas columnas denen tener una distribucion normal 
# agregar una columna llamada #precision" que tenga distribucion normal con mu = 0.92, sigma= 0.8

# %%
str(5).zfill(5)
crea un string pero rellena los caracteres con zeros
# Out:
# '00005'

# %%
tipos_sujetos
# Out:
# ['S00', 'S01', 'S02', 'S03']

# %%
tipos_sujetos = ['S'+str(i).zfill(2) for i in range(4)]
longitud =200
enteros = np.random.randint (0,4, size=longitud)
sujetos = ['S'+str(i).zfill(2) for i in enteros]
sujetos
# Out:
# ['S01',
#  'S00',
#  'S00',
#  'S01',
#  'S01',
#  'S00',
#  'S00',
#  'S02',
#  'S02',
#  'S03',
#  'S02',
#  'S03',
#  'S03',
#  'S00',
#  'S02',
#  'S03',
#  'S01',
#  'S00',
#  'S02',
#  'S03',
#  'S00',
#  'S03',
#  'S01',
#  'S03',
#  'S00',
#  'S00',
#  'S03',
#  'S02',
#  'S03',
#  'S01',
#  'S03',
#  'S03',
#  'S01',
#  'S00',
#  'S03',
#  'S00',
#  'S02',
#  'S00',
#  'S02',
#  'S01',
#  'S01',
#  'S03',
#  'S01',
#  'S02',
#  'S01',
#  'S01',
#  'S03',
#  'S03',
#  'S02',
#  'S03',
#  'S03',
#  'S03',
#  'S02',
#  'S03',
#  'S03',
#  'S00',
#  'S02',
#  'S03',
#  'S01',
#  'S01',
#  'S02',
#  'S02',
#  'S02',
#  'S03',
#  'S00',
#  'S00',
#  'S03',
#  'S02',
#  'S02',
#  'S00',
#  'S01',
#  'S00',
#  'S00',
#  'S02',
#  'S00',
#  'S01',
#  'S01',
#  'S02',
#  'S00',
#  'S02',
#  'S02',
#  'S02',
#  'S01',
#  'S00',
#  'S03',
#  'S00',
#  'S01',
#  'S02',
#  'S02',
#  'S03',
#  'S02',
#  'S02',
#  'S01',
#  'S00',
#  'S02',
#  'S00',
#  'S01',
#  'S03',
#  'S02',
#  'S00',
# ...

# %%
tipos_sujetos = ['S'+str(i).zfill(2) for i in range(4)]
longitud=200
ops_sujetos =np.random.randint (len(tipos_sujetos),size=longitud)
sujetos2= [tipos_sujetos[i] for i in ops_sujetos]
sujetos2

### otra forma
# Out:
# ['S03',
#  'S03',
#  'S00',
#  'S01',
#  'S02',
#  'S01',
#  'S01',
#  'S02',
#  'S02',
#  'S00',
#  'S00',
#  'S02',
#  'S02',
#  'S02',
#  'S01',
#  'S02',
#  'S03',
#  'S00',
#  'S00',
#  'S02',
#  'S01',
#  'S00',
#  'S02',
#  'S03',
#  'S03',
#  'S00',
#  'S02',
#  'S02',
#  'S02',
#  'S01',
#  'S02',
#  'S01',
#  'S01',
#  'S00',
#  'S02',
#  'S03',
#  'S03',
#  'S03',
#  'S02',
#  'S02',
#  'S03',
#  'S00',
#  'S03',
#  'S03',
#  'S02',
#  'S01',
#  'S02',
#  'S02',
#  'S02',
#  'S02',
#  'S03',
#  'S02',
#  'S00',
#  'S01',
#  'S01',
#  'S00',
#  'S00',
#  'S03',
#  'S01',
#  'S01',
#  'S01',
#  'S02',
#  'S01',
#  'S00',
#  'S00',
#  'S00',
#  'S03',
#  'S01',
#  'S03',
#  'S00',
#  'S02',
#  'S00',
#  'S00',
#  'S01',
#  'S00',
#  'S02',
#  'S02',
#  'S00',
#  'S02',
#  'S02',
#  'S03',
#  'S00',
#  'S02',
#  'S02',
#  'S00',
#  'S03',
#  'S01',
#  'S02',
#  'S00',
#  'S00',
#  'S01',
#  'S03',
#  'S02',
#  'S03',
#  'S03',
#  'S03',
#  'S00',
#  'S01',
#  'S01',
#  'S02',
# ...

# %%
generos = ['M', 'F']
longitud=200
ops_generos = np.random.randint(len(generos),size=longitud)
gen = []
for x in ops_generos:
    if x == 0:
        gen.append('M')
    else:
        gen.append('F')
gen
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[200], line 10
#       8     else:
#       9         gen.append('F')
# ---> 10 print(gen.head(5))
#
# AttributeError: 'list' object has no attribute 'head'

# %%
generos = ['M', 'F']
longitud=200
ops_gens = np.random.randint(len(generos),size=longitud)
lista_generos = [generos[i] for i in ops_gens]
lista_generos
# Out:
# ['F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'F',
#  'M',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
# ...

# %%
condicion = ['control', 'experimental']
longitud=200
ops_cond = np.random.randint(len(condicion),size=longitud)
lista_condicion = [condicion[i] for i in ops_cond]
lista_condicion
# Out:
# ['experimental',
#  'experimental',
#  'control',
#  'experimental',
#  'experimental',
#  'control',
#  'experimental',
#  'control',
#  'experimental',
#  'control',
#  'experimental',
#  'control',
#  'experimental',
#  'experimental',
#  'experimental',
#  'control',
#  'experimental',
#  'control',
#  'control',
#  'control',
#  'control',
#  'experimental',
#  'control',
#  'control',
#  'experimental',
#  'experimental',
#  'experimental',
#  'control',
#  'control',
#  'control',
#  'experimental',
#  'experimental',
#  'control',
#  'experimental',
#  'experimental',
#  'control',
#  'control',
#  'control',
#  'experimental',
#  'experimental',
#  'experimental',
#  'experimental',
#  'control',
#  'control',
#  'experimental',
#  'control',
#  'experimental',
#  'experimental',
#  'control',
#  'control',
#  'experimental',
#  'experimental',
#  'experimental',
#  'control',
#  'experimental',
#  'experimental',
#  'control',
#  'control',
#  'control',
#  'control',
# ...

# %%
region = ['hipocampo','cortex prefrontal', 'amigdala']
longitud=200
ops_reg = np.random.randint(len(region),size=longitud)
lista_region = [region[i] for i in ops_reg]
lista_region
# Out:
# ['cortex prefrontal',
#  'cortex prefrontal',
#  'hipocampo',
#  'hipocampo',
#  'cortex prefrontal',
#  'cortex prefrontal',
#  'cortex prefrontal',
#  'cortex prefrontal',
#  'amigdala',
#  'amigdala',
#  'cortex prefrontal',
#  'amigdala',
#  'hipocampo',
#  'amigdala',
#  'amigdala',
#  'hipocampo',
#  'amigdala',
#  'hipocampo',
#  'hipocampo',
#  'amigdala',
#  'hipocampo',
#  'hipocampo',
#  'amigdala',
#  'hipocampo',
#  'hipocampo',
#  'cortex prefrontal',
#  'amigdala',
#  'cortex prefrontal',
#  'cortex prefrontal',
#  'amigdala',
#  'hipocampo',
#  'amigdala',
#  'cortex prefrontal',
#  'cortex prefrontal',
#  'hipocampo',
#  'cortex prefrontal',
#  'cortex prefrontal',
#  'hipocampo',
#  'hipocampo',
#  'amigdala',
#  'hipocampo',
#  'amigdala',
#  'hipocampo',
#  'hipocampo',
#  'amigdala',
#  'amigdala',
#  'amigdala',
#  'amigdala',
#  'hipocampo',
#  'cortex prefrontal',
#  'amigdala',
#  'amigdala',
#  'cortex prefrontal',
#  'hipocampo',
#  'hipocampo',
# ...

# %%
neurotransmisor = ['dopamina','serotonina']
longitud=200
ops_neuro = np.random.randint(len(neurotransmisor),size=longitud)
lista_neurot = [neurotransmisor[i] for i in ops_neuro]
lista_neurot
# Out:
# ['dopamina',
#  'dopamina',
#  'dopamina',
#  'serotonina',
#  'serotonina',
#  'dopamina',
#  'serotonina',
#  'dopamina',
#  'serotonina',
#  'dopamina',
#  'serotonina',
#  'dopamina',
#  'serotonina',
#  'dopamina',
#  'dopamina',
#  'dopamina',
#  'serotonina',
#  'dopamina',
#  'dopamina',
#  'dopamina',
#  'serotonina',
#  'serotonina',
#  'dopamina',
#  'serotonina',
#  'serotonina',
#  'serotonina',
#  'serotonina',
#  'dopamina',
#  'serotonina',
#  'serotonina',
#  'dopamina',
#  'dopamina',
#  'dopamina',
#  'dopamina',
#  'serotonina',
#  'serotonina',
#  'serotonina',
#  'dopamina',
#  'dopamina',
#  'dopamina',
#  'serotonina',
#  'dopamina',
#  'dopamina',
#  'dopamina',
#  'dopamina',
#  'serotonina',
#  'dopamina',
#  'serotonina',
#  'serotonina',
#  'dopamina',
#  'serotonina',
#  'serotonina',
#  'serotonina',
#  'serotonina',
#  'dopamina',
#  'serotonina',
#  'dopamina',
#  'dopamina',
#  'dopamina',
#  'dopamina',
#  'dopamina',
#  'dopamina',
#  'dopamina',
# ...

# %%
tipos_sujetos = ['S'+str(i).zfill(2) for i in range(4)]
generos = ['M', 'F']
condicion = ['control', 'experimental']
region = ['hipocampo','cortex prefrontal', 'amigdala']
neurotransmisor = ['dopamina','serotonina']

longitud = 200
variables = [tipos_sujetos, generos, condicion, region, neurotransmisor]
data = []

for variable in variables:
    opciones = np.random.randint(len(variable), size=longitud)
    data.append([variable[i] for i in opciones])

df = pd.DataFrame(data).transpose()
df.columns = ['sujeto','genero','condicion','region','neuro']
df
# Out:
#     sujeto genero     condicion             region       neuro
# 0      S02      M       control          hipocampo    dopamina
# 1      S01      M       control          hipocampo    dopamina
# 2      S02      M       control          hipocampo  serotonina
# 3      S00      M  experimental           amigdala  serotonina
# 4      S03      M  experimental  cortex prefrontal    dopamina
# ..     ...    ...           ...                ...         ...
# 195    S02      M  experimental           amigdala    dopamina
# 196    S02      F       control  cortex prefrontal  serotonina
# 197    S02      F  experimental          hipocampo    dopamina
# 198    S01      M       control          hipocampo  serotonina
# 199    S03      M       control           amigdala    dopamina
#
# [200 rows x 5 columns]

# %%
## estas columnas denen tener una distribucion normal 
# agregar una columna llamada #precision" que tenga distribucion normal con mu = 0.92, sigma= 0.8
mu,sigma= 0.92, 0.8
longitud=200
preci = np.random.normal(mu,sigma, size= longitud)

df['precision'] = preci
df
# Out:
#     sujeto genero     condicion             region       neuro  precision
# 0      S02      M       control          hipocampo    dopamina   1.318735
# 1      S01      M       control          hipocampo    dopamina   0.111021
# 2      S02      M       control          hipocampo  serotonina   1.093755
# 3      S00      M  experimental           amigdala  serotonina   0.671109
# 4      S03      M  experimental  cortex prefrontal    dopamina   0.321676
# ..     ...    ...           ...                ...         ...        ...
# 195    S02      M  experimental           amigdala    dopamina   2.426277
# 196    S02      F       control  cortex prefrontal  serotonina   1.809573
# 197    S02      F  experimental          hipocampo    dopamina   2.138219
# 198    S01      M       control          hipocampo  serotonina   2.464274
# 199    S03      M       control           amigdala    dopamina   0.494730
#
# [200 rows x 6 columns]

# %%
## histograma de cuantos datos por sujueto se tienen

## mostrar en un histogram la proporcion de neurotransmisor

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(3,3))
plt.hist(df['sujeto'], color="lightblue");
## sin el figsize se hace grande

# %%
plt.figure(figsize=(3,3))
plt.hist(df['neuro'], color="lightblue");

# %%
# para cada sujeto sacar la proporcion del tipo de condicion
# para cada sujeto, calcular el maximo, el minimo, y la media de su precision
## para cada condicion, hcer el hhistograma de las regiones activadas
## hacerlo mediante 2 metodos: filtrado de dataframes y usando groupby

# %%
prop = df [df['sujeto'] == 'S00']
proporcion = prop['condicion'].value_counts(normalize=True)

print('proporcion: S01')
proporcion
# Out:
# proporcion: S01
# condicion
# experimental    0.578947
# control         0.421053
# Name: proportion, dtype: float64

# %%
prop1 = df [df['sujeto'] == 'S01']
proporcion1 = prop1['condicion'].value_counts(normalize=True)

print('proporcion: S01')
proporcion1
# Out:
# proporcion: S01
# condicion
# control         0.528302
# experimental    0.471698
# Name: proportion, dtype: float64

# %%
prop2 = df [df['sujeto'] == 'S02']
proporcion2 = prop2['condicion'].value_counts(normalize=True)

print('proporcion: S02')
proporcion2
# Out:
# proporcion: S02
# condicion
# experimental    0.618182
# control         0.381818
# Name: proportion, dtype: float64

# %%
prop3 = df [df['sujeto'] == 'S03']
proporcion3 = prop3['condicion'].value_counts(normalize=True)

print('proporcion: S03')
proporcion3
# Out:
# proporcion: S03
# condicion
# control         0.537037
# experimental    0.462963
# Name: proportion, dtype: float64

# %%
proporciones = (
    df.groupby("sujeto")["condicion"]
      .value_counts(normalize=True)
      .reset_index()
)

proporciones
# Out:
#   sujeto     condicion  proportion
# 0    S00  experimental    0.578947
# 1    S00       control    0.421053
# 2    S01       control    0.528302
# 3    S01  experimental    0.471698
# 4    S02  experimental    0.618182
# 5    S02       control    0.381818
# 6    S03       control    0.537037
# 7    S03  experimental    0.462963

# %%
# para cada sujeto, calcular el maximo, el minimo, y la media de su precisionp<
calculos = df [df['sujeto'] == 'S00']
suj = calculos['precision']

print('mínimo S00:')
print(suj.min())

print('máximo S00:')
print(suj.max())

print('media S00:')
print(suj.mean())
# Out:
# mínimo S00:
# -0.8923197513503635
# máximo S00:
# 3.1342928266563823
# media S00:
# 1.0156010880557478

# %%
calculos1 = df [df['sujeto'] == 'S01']
suj1 = calculos1['precision']

print('mínimo S00:')
print(suj1.min())

print('máximo S00:')
print(suj1.max())

print('media S00:')
print(suj1.mean())
# Out:
# mínimo S00:
# -0.8518299985560144
# máximo S00:
# 2.7682744448723127
# media S00:
# 0.9893020756649225

# %%
calculos2 = df [df['sujeto'] == 'S02']
suj2 = calculos2['precision']

print('mínimo S02:')
print(suj2.min())

print('máximo S02:')
print(suj2.max())

print('media S02:')
print(suj2.mean())
# Out:
# mínimo S02:
# -0.4042324323552263
# máximo S02:
# 2.650182056813477
# media S02:
# 0.9495312352769725

# %%
calculos3 = df [df['sujeto'] == 'S03']
suj3 = calculos3['precision']

print('mínimo S03:')
print(suj3.min())

print('máximo S03:')
print(suj3.max())

print('media S03:')
print(suj3.mean())
# Out:
# mínimo S03:
# -0.9555749000390509
# máximo S03:
# 2.937572391648982
# media S03:
# 1.0761152822174809

# %%
df_por_sujeto = df.groupby(by='sujeto')
df_por_sujeto.describe()
# Out:
#        precision                                                              \
#            count      mean       std       min       25%       50%       75%
# sujeto
# S00         38.0  1.015601  0.847532 -0.892320  0.494497  1.026884  1.529271
# S01         53.0  0.989302  0.842839 -0.851830  0.247316  1.105203  1.620072
# S02         55.0  0.949531  0.740339 -0.404232  0.402841  0.876486  1.458768
# S03         54.0  1.076115  0.900602 -0.955575  0.518574  1.022260  1.592141
#
#
#              max
# sujeto
# S00     3.134293
# S01     2.768274
# S02     2.650182
# S03     2.937572

# %%
## para cada condicion, hcer el histograma de las regiones activadas
c_control = df [df['condicion']== 'control']

plt.figure(figsize=(3,3))
plt.hist(c_control["region"], color="lightgreen", rwidth=2)
plt.title("Histograma de regiones activadas en condición control")
plt.xlabel("Region")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
c_exp = df [df['condicion']== 'experimental']

plt.figure(figsize=(3,3))
plt.hist(c_exp["region"], color="lightgreen", rwidth=2)

plt.title("Histograma de regiones activadas en condición experimental")
plt.xlabel("Region")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
df.groupby(by='sujeto').groups.values()
# Out:
# dict_values([Index([  3,  19,  29,  31,  35,  50,  58,  79,  86,  87,  91,  99, 100, 101,
#        106, 107, 115, 122, 123, 126, 132, 134, 135, 146, 148, 153, 158, 159,
#        160, 163, 165, 171, 173, 176, 177, 178, 185, 188],
#       dtype='int64'), Index([  1,   6,   7,  12,  13,  14,  15,  18,  23,  28,  36,  40,  44,  45,
#         47,  51,  54,  56,  57,  59,  61,  64,  66,  67,  68,  74,  76,  80,
#         83,  88,  89,  90, 104, 105, 108, 112, 118, 128, 139, 144, 147, 149,
#        157, 164, 170, 172, 181, 182, 184, 186, 187, 190, 198],
#       dtype='int64'), Index([  0,   2,   8,  10,  17,  20,  24,  30,  34,  38,  39,  41,  48,  49,
#         53,  60,  69,  70,  72,  73,  75,  78,  82,  84,  85,  92,  93,  94,
#         97, 102, 103, 109, 111, 116, 117, 119, 120, 125, 127, 130, 131, 136,
#        137, 138, 141, 154, 161, 169, 174, 191, 192, 193, 195, 196, 197],
#       dtype='int64'), Index([  4,   5,   9,  11,  16,  21,  22,  25,  26,  27,  32,  33,  37,  42,
# ...

# %%
df.groupby(by='sujeto').get_group('S00').head(3)
# Out:
#    sujeto genero     condicion             region       neuro  precision
# 3     S00      M  experimental           amigdala  serotonina   0.671109
# 19    S00      F       control  cortex prefrontal  serotonina   3.134293
# 29    S00      F       control          hipocampo  serotonina   1.076333

# %%
grupos = df.groupby(by=['sujeto','condicion'])
grupos

# %%
llaves=grupos.groups.keys()
llaves
# Out:
# dict_keys([('S00', 'control'), ('S00', 'experimental'), ('S01', 'control'), ('S01', 'experimental'), ('S02', 'control'), ('S02', 'experimental'), ('S03', 'control'), ('S03', 'experimental')])

# %%
list(llaves)[0]
# Out:
# ('S00', 'control')

# %%
grupos.get_group(list(llaves)[0])
# Out:
#     sujeto genero condicion             region       neuro  precision
# 19     S00      F   control  cortex prefrontal  serotonina   3.134293
# 29     S00      F   control          hipocampo  serotonina   1.076333
# 35     S00      F   control           amigdala  serotonina  -0.892320
# 50     S00      F   control           amigdala  serotonina   0.796315
# 58     S00      F   control          hipocampo    dopamina  -0.238745
# 79     S00      M   control           amigdala    dopamina   0.248773
# 99     S00      M   control          hipocampo    dopamina   2.501880
# 101    S00      F   control          hipocampo    dopamina   1.606984
# 126    S00      F   control  cortex prefrontal  serotonina   1.111260
# 135    S00      F   control           amigdala  serotonina   1.233328
# 146    S00      M   control  cortex prefrontal    dopamina   0.956217
# 159    S00      F   control  cortex prefrontal  serotonina   0.413285
# ...

# %%
grupos.get_group(list(llaves)[0]).head(3)
# Out:
#    sujeto genero condicion             region       neuro  precision
# 19    S00      F   control  cortex prefrontal  serotonina   3.134293
# 29    S00      F   control          hipocampo  serotonina   1.076333
# 35    S00      F   control           amigdala  serotonina  -0.892320

# %%
ccontrol = df [df['sujeto'] == 'S00']
sujeto0 = ccontrol[ccontrol['condicion']== 'control']

sujeto0.head(3)
# Out:
#    sujeto genero condicion             region       neuro  precision
# 19    S00      F   control  cortex prefrontal  serotonina   3.134293
# 29    S00      F   control          hipocampo  serotonina   1.076333
# 35    S00      F   control           amigdala  serotonina  -0.892320

# %%
### o tambien puede hacerse en una sola linea
sjo = df[(df.sujeto=='S00') & (df.condicion=='control')]
sjo.head(5)
# Out:
#    sujeto genero condicion             region       neuro  precision
# 19    S00      F   control  cortex prefrontal  serotonina   3.134293
# 29    S00      F   control          hipocampo  serotonina   1.076333
# 35    S00      F   control           amigdala  serotonina  -0.892320
# 50    S00      F   control           amigdala  serotonina   0.796315
# 58    S00      F   control          hipocampo    dopamina  -0.238745

# %%
## tambien se puede poner or(|) o negacion (~)
suj0= df[(df.sujeto=='S00') & ~ (df.condicion=='control')]
suj0.head(3)
# Out:
#    sujeto genero     condicion    region       neuro  precision
# 3     S00      M  experimental  amigdala  serotonina   0.671109
# 31    S00      F  experimental  amigdala    dopamina   2.077332
# 86    S00      F  experimental  amigdala    dopamina   1.114769

# %%
sujj= df[(df.sujeto=='S00') & (df.condicion!='control')]
sujj.head(3)
# Out:
#    sujeto genero     condicion    region       neuro  precision
# 3     S00      M  experimental  amigdala  serotonina   0.671109
# 31    S00      F  experimental  amigdala    dopamina   2.077332
# 86    S00      F  experimental  amigdala    dopamina   1.114769
