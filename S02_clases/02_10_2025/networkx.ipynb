# %%
import networkx as nx

# %%
G =nx.Graph()

# %%
G.nodes(), G.edges
# Out:
# (NodeView(()), EdgeView([]))

# %%
G.add_nodes_from([ 'A', 'B', 'C', 'D', 'E' ])

# %%
G.nodes(), G.edges
# Out:
# (NodeView(('B', 'A', 'C', 'D', 'E')), EdgeView([]))

# %%
G.add_edges_from([ ('B', 'C'), ('C', 'A'), ('D', 'E')])

# %%
G.nodes(), G.edges
# Out:
# (NodeView(('B', 'A', 'C', 'D', 'E')),
#  EdgeView([('B', 'C'), ('A', 'C'), ('D', 'E')]))

# %%
G.add_edge('C','D')
nx.draw_networkx(G)
