# %%
import numpy as np
import pandas as pd
import networkx as nx

import seaborn as sns
import matplotlib.pyplot as plt
import scipy.io
import networkx.algorithms.smallworld as sw
import networkx.algorithms.community as nx_comm
import mne
from scipy.signal import coherence, hilbert

# %%
# !pip install mne
# Out:
# Collecting mne
#   Downloading mne-1.10.2-py3-none-any.whl (7.4 MB)
#      ---------------------------------------- 7.4/7.4 MB 16.9 MB/s eta 0:00:00
# Requirement already satisfied: decorator in c:\users\v304-16\appdata\local\programs\python\python311\lib\site-packages (from mne) (5.2.1)
# Requirement already satisfied: jinja2 in c:\users\v304-16\appdata\local\programs\python\python311\lib\site-packages (from mne) (3.1.6)
# Collecting lazy-loader>=0.3
#   Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Requirement already satisfied: matplotlib>=3.7 in c:\users\v304-16\appdata\local\programs\python\python311\lib\site-packages (from mne) (3.10.7)
# Requirement already satisfied: numpy<3,>=1.25 in c:\users\v304-16\appdata\local\programs\python\python311\lib\site-packages (from mne) (2.3.3)
# Requirement already satisfied: packaging in c:\users\v304-16\appdata\local\programs\python\python311\lib\site-packages (from mne) (25.0)
# Collecting pooch>=1.5
#   Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
#      ---------------------------------------- 64.6/64.6 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.11 in c:\users\v304-16\appdata\local\programs\python\python311\lib\site-packages (from mne) (1.16.3)
# Collecting tqdm
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.5/78.5 kB ? eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\v304-16\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.7->mne) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\v304-16\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.7->mne) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\v304-16\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.7->mne) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\v304-16\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.7->mne) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\v304-16\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.7->mne) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\v304-16\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.7->mne) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\v304-16\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.7->mne) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\v304-16\appdata\local\programs\python\python311\lib\site-packages (from pooch>=1.5->mne) (4.3.8)
# Requirement already satisfied: requests>=2.19.0 in c:\users\v304-16\appdata\local\programs\python\python311\lib\site-packages (from pooch>=1.5->mne) (2.32.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\v304-16\appdata\local\programs\python\python311\lib\site-packages (from jinja2->mne) (3.0.2)
# Requirement already satisfied: colorama in c:\users\v304-16\appdata\local\programs\python\python311\lib\site-packages (from tqdm->mne) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\v304-16\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.7->mne) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\v304-16\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\v304-16\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\v304-16\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\v304-16\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2025.8.3)
# Installing collected packages: tqdm, lazy-loader, pooch, mne
# Successfully installed lazy-loader-0.4 mne-1.10.2 pooch-1.8.2 tqdm-4.67.1
# [notice] A new release of pip available: 22.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# hubs mas grandes y diferente color de cada comunidad, hubs con aristas de diferente color
edf_path=r"C:\Users\V304-16\Documents\GitHub\Neurociencias-2026-1\S03_datasets\EEG_practica\chb01_01.edf"
sfreq_target=256 #frecuencias demuestreo a la que estamos normalizando
fmin,fmax=8,13 #banda alfa para la coherencia
raw= mne.io.read_raw_edf(edf_path, preload=True)
raw.resample(sfreq_target)
raw.filter(1.,45.,fir_design='firwin')
data= raw.get_data()
ch_names = raw.info['ch_names']
n_channels = len(ch_names)
# Out:
# Extracting EDF parameters from C:\Users\V304-16\Documents\GitHub\Neurociencias-2026-1\S03_datasets\EEG_practica\chb01_01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\V304-16\AppData\Local\Temp\ipykernel_9300\501536158.py:5: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw= mne.io.read_raw_edf(edf_path, preload=True)
# Sampling frequency of the instance is already 256.0, returning unmodified.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)

# %%
# ====== 2. MATRIZ DE COHERENCIA ESPECTRAL ======use esta matriz porque según lo que investigué es la mas adecuada para analizar datos de EEG
coh_matrix = np.zeros((n_channels, n_channels))
for i in range(n_channels):
    for j in range(n_channels):
        f, Cxy = coherence(data[i], data[j], fs=sfreq_target, nperseg=sfreq_target*2)
        mask = (f >= fmin) & (f <= fmax)
        coh_matrix[i, j] = np.mean(Cxy[mask])

coh_df = pd.DataFrame(coh_matrix, index=ch_names, columns=ch_names)
np.fill_diagonal(coh_df.values, 0)

# %%
G=nx.from_pandas_adjacency(coh_df)
communidades=nx_comm.louvain_communities(G, weight='weight')
print(f'Numero de comunidades:{len(communidades)},Tamaño de cada comunidad:{[len(i) for i in communidades]}')
# Out:
# Numero de comunidades:5,Tamaño de cada comunidad:[7, 7, 5, 2, 2]

# %%
#Calcular hubs
hubs=sorted(G.degree(weight='weight'),key=lambda x: x[1],reverse=True)[0:5]

# %%
coord3d=r"C:\Users\V304-16\Documents\GitHub\Neurociencias-2026-1\S03_datasets\EEG_practica\coordenadas_bipolares_eeg.csv"
coord=pd.read_csv(coord3d)
coord.set_index('canal', inplace=True, drop=True)
coh_df.columns = [columna.split(sep = ' ')[0] for columna in coh_df.columns]
coh_df.index = coh_df.columns

# %%
coord_df=pd.DataFrame(coord, columns=['x', 'y', 'z'])

pos3D={canal:(coord_df.loc[canal,'x'],
             coord_df.loc[canal,'y'],
             coord_df.loc[canal,'z']) for canal in coord_df.index}
GG = nx.from_pandas_adjacency(coh_df, create_using=nx.DiGraph());

fig= plt.figure(figsize=(4,4))
ax= fig.add_subplot(111, projection='3d')

for i, (x,y,z) in pos3D.items():
    ax.scatter(x,y,z)

for i,j, data in GG.edges(data=True):
    x=[pos3D[i][0],pos3D[j][0]]
    y=[pos3D[i][1],pos3D[j][1]]
    z=[pos3D[i][2],pos3D[j][2]]
    ax.plot(x,y,z,linewidth=data['weight']*2)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('EEG 3D')
plt.show()
