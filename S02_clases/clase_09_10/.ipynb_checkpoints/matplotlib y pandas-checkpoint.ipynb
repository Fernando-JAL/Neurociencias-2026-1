# %% [markdown]
# NUMPY

# %%
import numpy as np

# %%
np.random.rand(6, 2)
# Out:
# array([[0.53930791, 0.46053721],
#        [0.9951857 , 0.34331656],
#        [0.75426729, 0.74667553],
#        [0.64711368, 0.38613413],
#        [0.57065795, 0.56712581],
#        [0.49229729, 0.43054483]])

# %%
a, b = 10, 15
np.random.uniform(a, b, size = [3,4])
# Out:
# array([[13.30053784, 14.4518836 , 10.87226521, 11.35565306],
#        [10.17824329, 14.23534125, 12.99161852, 10.31445515],
#        [10.06154356, 13.59099639, 13.32250511, 14.010735  ]])

# %%
np.random.randint(10, size = [22])
# Out:
# array([3, 9, 6, 1, 3, 0, 4, 8, 9, 8, 6, 5, 7, 9, 9, 1, 0, 7, 6, 4, 3, 3],
#       dtype=int32)

# %%
np.random.normal()
# Out:
# -1.6367439731838505

# %%
mu, sigma = -8, 4
np.random.normal(mu, sigma, size=[2, 6])
# Out:
# array([[ -7.88402059,  -4.09164272, -12.54118772, -10.44526955,
#          -5.5090737 ,  -5.76688   ],
#        [-12.67182812, -15.6145388 ,  -0.19824579,  -5.90432241,
#         -12.19739235,  -8.45315301]])

# %%
valores = np.random.normal (0,1, size = 100000)
np.mean(valores), np.std(valores)
# Out:
# (np.float64(0.0023183009981251963), np.float64(1.0016921873824154))

# %%
vec1, vec2 = np.array([2, 3, 4]), np.array([-1, -10, 0]) 
np.vdot(vec1, vec2)
# Out:
# np.int64(-32)

# %%
vec2.sort()
vec2[::-1]
# Out:
# array([-10,  -1,   0])

# %%
import matplotlib.pyplot

# %%
import pandas

# %%
import matplotlib.pyplot as plt

# %%
valores = np.arange(20)

# %%
valores = np.arange(20)
plt.plot(valores,  marker = '.')

# %%
valores = np.random.uniform(size = 5)
plt.hist(valores)
# Out:
# (array([2., 0., 0., 0., 0., 2., 0., 0., 0., 1.]),
#  array([0.0196117 , 0.1094778 , 0.19934389, 0.28920999, 0.37907608,
#         0.46894217, 0.55880827, 0.64867436, 0.73854046, 0.82840655,
#         0.91827265]),
#  <BarContainer object of 10 artists>)

# %%
valores
# Out:
# array([0.0196117 , 0.02563277, 0.91827265, 0.55221584, 0.52902757])

# %%
#EJERCICIO -> crear un arreglo de numero s aleatroios
#con distribución normal con media mu = 0 y desviación estandar = 1 
#de tamaño 100,000 y plotear su histograma
mu, sigma = 0, 1 
valores = np.random.normal(mu, sigma, size = 100000)
plt.hist(valores, bins= 100)
# Out:
# (array([1.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 1.000e+00, 0.000e+00,
#         2.000e+00, 2.000e+00, 3.000e+00, 4.000e+00, 3.000e+00, 1.100e+01,
#         1.500e+01, 1.500e+01, 1.600e+01, 1.900e+01, 4.000e+01, 3.800e+01,
#         5.500e+01, 6.700e+01, 9.000e+01, 1.250e+02, 1.490e+02, 1.990e+02,
#         2.270e+02, 2.700e+02, 3.540e+02, 4.100e+02, 4.690e+02, 5.920e+02,
#         7.120e+02, 8.000e+02, 9.520e+02, 1.036e+03, 1.298e+03, 1.378e+03,
#         1.573e+03, 1.778e+03, 1.934e+03, 2.173e+03, 2.341e+03, 2.533e+03,
#         2.668e+03, 2.835e+03, 3.053e+03, 3.266e+03, 3.140e+03, 3.387e+03,
#         3.432e+03, 3.553e+03, 3.486e+03, 3.542e+03, 3.406e+03, 3.516e+03,
#         3.362e+03, 3.355e+03, 3.209e+03, 2.951e+03, 2.843e+03, 2.582e+03,
#         2.440e+03, 2.319e+03, 2.109e+03, 1.879e+03, 1.724e+03, 1.551e+03,
#         1.346e+03, 1.209e+03, 9.850e+02, 8.200e+02, 7.760e+02, 6.510e+02,
#         5.430e+02, 4.590e+02, 3.650e+02, 3.350e+02, 2.320e+02, 2.310e+02,
# ...

# %%
import pandas as pd # series y dataframes hace

# %%
pd.Series([4, 5, 6, 7, 8, 9, 'casa']) # la columna de la derecha es el índice indica cuantos datos hay y la otra es los datos
# Out:
# 0       4
# 1       5
# 2       6
# 3       7
# 4       8
# 5       9
# 6    casa
# dtype: object

# %%
pd.Series(range(50 , 56), index = ['a', 'b', 'c', 'd', 'e', 'f'])
# Out:
# a    50
# b    51
# c    52
# d    53
# e    54
# f    55
# dtype: int64

# %%
serie = pd.Series([5, 6, 7, 8, 9], index = ['a', 'b', 'c', 'd', 'e'])
serie['b']
# Out:
# np.int64(6)
