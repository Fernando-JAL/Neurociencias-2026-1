# %%
import numpy as np

# %%
a,b=10,15

# %%
np.random.uniform(a,b,size=[3,4])
# Out:
# array([[14.48229021, 14.3453233 , 12.11745337, 12.83585298],
#        [11.67522694, 12.13038068, 14.27817421, 14.89558897],
#        [13.25735533, 10.99291985, 11.59700517, 11.28698639]])

# %%
np.random.randint(10, size=[22])
# Out:
# array([7, 7, 2, 4, 1, 1, 3, 8, 8, 8, 6, 1, 0, 4, 8, 8, 7, 2, 0, 9, 0, 1],
#       dtype=int32)

# %%
np.random.normal()
# Out:
# 1.5076724051611334

# %%
valores= np.random.normal(0,1, size=100000000)

# %%
valores= np.random.normal(0,1, size=100000)
np.mean(valores),np.std(valores)
# Out:
# (np.float64(0.0005450834868948654), np.float64(1.001142381216187))

# %%
import matplotlib

# %%
import pandas

# %%
import matplotlib.pyplot as plt

# %%
valores= np.arange(20)
plt.plot(valores,'.')

# %%
valores= np.random.uniform(size=5)
plt.hist(valores)
# Out:
# (array([1., 0., 0., 2., 0., 1., 0., 0., 0., 1.]),
#  array([0.2960641 , 0.34076797, 0.38547183, 0.43017569, 0.47487956,
#         0.51958342, 0.56428728, 0.60899115, 0.65369501, 0.69839887,
#         0.74310274]),
#  <BarContainer object of 10 artists>)

# %%
valores= np.random.uniform(size=10000000)
plt.hist(valores)
# Out:
# (array([ 999229., 1001477., 1000803., 1000239.,  999463.,  999460.,
#          999724., 1000790.,  999775.,  999040.]),
#  array([2.30994001e-08, 1.00000002e-01, 1.99999980e-01, 2.99999958e-01,
#         3.99999937e-01, 4.99999915e-01, 5.99999894e-01, 6.99999872e-01,
#         7.99999851e-01, 8.99999829e-01, 9.99999808e-01]),
#  <BarContainer object of 10 artists>)

# %%
#cree una variable aleatoria de numeros aleatorios con distribucion normal 
#cn media mu= 0 y desviacion estandar=1 de tamaño 
#100,000 y plotear su histograma

# %%
valores= np.random.normal(size=100000)
np.mean== 0,np.std== 1
# Out:
# (False, False)
