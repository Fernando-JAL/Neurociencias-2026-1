# %%
import numpy as np

# %%
np.random.rand(6, 2)
# Out:
# array([[0.98505469, 0.99010938],
#        [0.09845888, 0.28861638],
#        [0.64400056, 0.66524503],
#        [0.84553752, 0.21631087],
#        [0.98047972, 0.63047697],
#        [0.28250019, 0.7436231 ]])

# %%
a, b = 10, 15
np.random.uniform(a, b, size=[3, 4])
# Out:
# array([[13.11479674, 10.40506289, 13.85808527, 12.80117585],
#        [11.26759225, 14.99980733, 13.90167452, 14.96509117],
#        [11.74761665, 10.42208036, 13.32510962, 14.26026356]])

# %%
np.random.randint(10, size=[22])
# Out:
# array([6, 7, 6, 9, 8, 4, 5, 6, 1, 0, 7, 0, 0, 1, 5, 5, 1, 6, 2, 7, 6, 8],
#       dtype=int32)

# %%
np.random.normal()
# Out:
# 1.199880412551017

# %%
mu, sigma = -8, 4
np.random.normal(mu, sigma, size=[2, 6])
# Out:
# array([[ 1.08895623e-02, -1.42959475e+01, -4.15515018e+00,
#         -5.36806011e+00, -9.69597344e+00, -4.69290908e+00],
#        [-1.27105302e+01, -9.59112659e+00, -9.87866076e+00,
#         -9.52476283e+00, -1.13915233e+01, -1.06017426e+01]])

# %%
valores = np.random.normal(0, 1, size=10000000)
np.mean(valores), np.std(valores)
# Out:
# (np.float64(0.0003554019256502406), np.float64(0.9997814197983861))

# %%
vec1, vec2 = np.array([2, 3, 4]), np.array([-1, -10, 0])
np.vdot(vec1, vec2)
# Out:
# np.int64(-32)

# %%
vec2.sort()
vec2[::-1]
# Out:
# array([  0,  -1, -10])

# %%
import matplotlib.pyplot as plt

# %%
valores = np.arange(20)
plt.plot(valores, '.')

# %%
valores = np.random.uniform(size=1000000)
plt.hist(valores)
# Out:
# (array([100265.,  99745., 100060., 100073.,  99850.,  99995., 100206.,
#          99675.,  99757., 100374.]),
#  array([4.17160715e-07, 1.00000324e-01, 2.00000231e-01, 3.00000138e-01,
#         4.00000045e-01, 4.99999952e-01, 5.99999859e-01, 6.99999766e-01,
#         7.99999673e-01, 8.99999580e-01, 9.99999487e-01]),
#  <BarContainer object of 10 artists>)

# %%
# Ej. Crear una arreglo de números aleatorios 
# con distribución normal con media mu = 0 y desviación estándar = 1
# de tamaño 100,000 y plotear su histograma
mu, sigma = 0, 1
valores = np.random.normal(mu, sigma, size=100000)
plt.hist(valores, bins=100);
