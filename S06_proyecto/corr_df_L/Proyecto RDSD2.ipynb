MoveL_rest.csv",
r"C:\Users\Juan\Documents\GitHub\Neurociencias-2026-1\S06_proyecto\corr_df_L\corr_df_QZTsn6_MedOn_MoveL_task.csv",
r"C:\Users\Juan\Documents\GitHub\Neurociencias-2026-1\S06_proyecto\corr_df_L\corr_df_0cGdk9_MedOff_HoldL_rest.csv",
r"C:\Users\Juan\Documents\GitHub\Neurociencias-2026-1\S06_proyecto\corr_df_L\corr_df_0cGdk9_MedOff_HoldL_task.csv",
r"C:\Users\Juan\Documents\GitHub\Neurociencias-2026-1\S06_proyecto\corr_df_L\corr_df_0cGdk9_MedOff_MoveL_rest.csv",
r"C:\Users\Juan\Documents\GitHub\Neurociencias-2026-1\S06_proyecto\corr_df_L\corr_df_0cGdk9_MedOff_MoveL_task.csv",
r"C:\Users\Juan\Documents\GitHub\Neurociencias-2026-1\S06_proyecto\corr_df_L\corr_df_0cGdk9_MedOn_HoldL_rest.csv",
]

Med_Off_Rest = ['rest', 'MedOff']
Med_On_Rest = ['rest', 'MedOn']
Med_On_Task = ['task', 'MedOn']
Med_Off_Task = ['task', 'MedOff']

Med_Off_Rest_list = []
Med_On_Rest_list = []
Med_On_Task_list = []
Med_Off_Task_list = []

for path in paths:
    if all(key in path for key in Med_Off_Rest):
        read = pd.read_csv(path)
        read = read.values
        Med_Off_Rest_list.append(read)
    elif all(key in path for key in Med_On_Rest):
        read = pd.read_csv(path)
        read = read.values
        Med_On_Rest_list.append(read)

# %%
Med_On_Rest_list[3]
# Out:
# array([[ 0.00000000e+00,  1.00000000e+00,  4.01945539e-02, ...,
#          3.80292093e-02,  4.09365244e-02, -2.77975098e-02],
#        [ 1.00000000e+00,  4.01945539e-02,  1.00000000e+00, ...,
#         -4.39760144e-02, -2.75932905e-02,  1.34485479e-02],
#        [ 2.00000000e+00,  8.90699533e-02,  4.24992673e-02, ...,
#          3.96329229e-03, -1.69888782e-02,  1.56338370e-02],
#        ...,
#        [ 2.05000000e+02,  3.80292093e-02, -4.39760144e-02, ...,
#          1.00000000e+00,  1.06674259e-01,  4.81131572e-02],
#        [ 2.06000000e+02,  4.09365244e-02, -2.75932905e-02, ...,
#          1.06674259e-01,  1.00000000e+00, -7.97795763e-01],
#        [ 2.07000000e+02, -2.77975098e-02,  1.34485479e-02, ...,
#          4.81131572e-02, -7.97795763e-01,  1.00000000e+00]],
#       shape=(208, 209))

# %%
Med_Off_Rest_list[5]
# Out:
# array([[ 0.00000000e+00,  1.00000000e+00,  2.64522935e-01, ...,
#          2.49854183e-02,  1.31111163e-02, -2.98792520e-02],
#        [ 1.00000000e+00,  2.64522935e-01,  1.00000000e+00, ...,
#         -1.01580463e-02, -3.44115109e-02, -3.78471575e-02],
#        [ 2.00000000e+00,  5.25585569e-01,  4.26757940e-01, ...,
#          1.85918238e-02, -8.47115991e-02, -1.13545857e-01],
#        ...,
#        [ 2.07000000e+02,  2.49854183e-02, -1.01580463e-02, ...,
#          1.00000000e+00, -6.14037767e-02, -8.55082176e-02],
#        [ 2.08000000e+02,  1.31111163e-02, -3.44115109e-02, ...,
#         -6.14037767e-02,  1.00000000e+00,  1.09578308e-01],
#        [ 2.09000000e+02, -2.98792520e-02, -3.78471575e-02, ...,
#         -8.55082176e-02,  1.09578308e-01,  1.00000000e+00]],
#       shape=(210, 211))
